# %%
# ============================================
# Standard library imports
# ============================================

import sys
import re
import logging
import warnings
from pathlib import Path

from IPython.display import display

warnings.filterwarnings("ignore")


# ============================================
# Numeric / statistics
# ============================================

import numpy as np
import pandas as pd

import scipy
from scipy import stats
from scipy.stats import pearsonr, spearmanr


# ============================================
# Machine learning / multivariate analysis
# ============================================

from sklearn.preprocessing import PowerTransformer
from sklearn.decomposition import PCA
from scipy.cluster.hierarchy import (
    linkage,
    dendrogram,
)


# ============================================
# Plotting / visualization
# ============================================

import matplotlib as mpl
import matplotlib.pyplot as plt

from matplotlib.ticker import FuncFormatter
from matplotlib.gridspec import GridSpec
from matplotlib.lines import Line2D

import seaborn as sns

# Optional: raincloud plot
try:
    import ptitprince as pt
    HAS_PTITPRINCE = True
except ImportError:
    HAS_PTITPRINCE = False
    print("ptitprince is not installed. RainCloud plots will be skipped.")


# ============================================
# Version info
# ============================================

print(f"python  = {sys.version_info[0]}.{sys.version_info[1]}.{sys.version_info[2]}")
print(f"pandas  = {pd.__version__}")
print(f"numpy   = {np.__version__}")
print(f"scipy   = {scipy.__version__}")

if HAS_PTITPRINCE:
    print("ptitprince imported successfully")


# ============================================
# Logging
# ============================================

logging.root.handlers = []

stream_handler = logging.StreamHandler(sys.stderr)

logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s %(levelname)8s: %(message)s",
    handlers=[stream_handler],
)

logger = logging.getLogger(__name__)
logging.getLogger("matplotlib").setLevel(logging.WARNING)
# Out:
# python  = 3.11.15
# pandas  = 2.3.3
# numpy   = 2.4.6
# scipy   = 1.17.1
# ptitprince imported successfully

# %%
# ============================================
# Global plotting configuration
# ============================================

_PLOT_CFG = {
    "fig_w": 6.0,
    "fig_h": 6.0,
    "dpi": 300,
}


SPECIES_INFO = {
    "AT21": {
        "label": "AT",
        "short": "AT21",
        "color": "#664D0AFF",
        "marker": "o",
    },
    "NB21": {
        "label": "NB",
        "short": "NB21",
        "color": "#7e3131",
        "marker": "^",
    },
    "OS21": {
        "label": "OS",
        "short": "OS21",
        "color": "#13563f",
        "marker": "s",
    },
}

def set_plot_style(
    *,
    base_fontsize=10,
    title_fontsize=12,
    label_fontsize=10,
    tick_fontsize=9,
    legend_fontsize=10,
    dpi=300,
    axes_linewidth=1.2,
    spines_top=True,
    spines_right=True,
    tick_size_major=6,
    tick_dir="out",
    grid=False,
    fig_w=6.0,
    fig_h=6.0,
):
    sns.set_style("ticks")

    mpl.rcParams.update({
        "font.family": "DejaVu Sans",
        "font.size": base_fontsize,

        "axes.titlesize": title_fontsize,
        "axes.labelsize": label_fontsize,

        "xtick.labelsize": tick_fontsize,
        "ytick.labelsize": tick_fontsize,

        "legend.fontsize": legend_fontsize,

        "figure.dpi": dpi,
        "savefig.dpi": dpi,

        "axes.linewidth": axes_linewidth,
        "axes.spines.top": spines_top,
        "axes.spines.right": spines_right,
        "axes.grid": grid,
        "axes.axisbelow": True,

        "xtick.major.size": tick_size_major,
        "ytick.major.size": tick_size_major,
        "xtick.direction": tick_dir,
        "ytick.direction": tick_dir,

        "legend.frameon": False,

        "savefig.bbox": "tight",
        "savefig.transparent": False,
        "figure.autolayout": False,
    })

    _PLOT_CFG.update({
        "fig_w": fig_w,
        "fig_h": fig_h,
        "dpi": dpi,
    })


def make_fig(w=None, h=None, dpi=None):
    W = float(w) if w is not None else _PLOT_CFG["fig_w"]
    H = float(h) if h is not None else _PLOT_CFG["fig_h"]
    D = dpi if dpi is not None else _PLOT_CFG["dpi"]

    fig, ax = plt.subplots(
        figsize=(W, H),
        dpi=D,
    )

    return fig, ax


def _compact_formatter():
    def _fmt(x, _pos=None):
        axx = abs(x)

        if axx >= 1e9:
            s = f"{x / 1e9:.1f}B"
        elif axx >= 1e6:
            s = f"{x / 1e6:.1f}M"
        elif axx >= 1e3:
            s = f"{x / 1e3:.1f}k"
        else:
            s = f"{x:.2g}"

        return (
            s.replace(".0B", "B")
             .replace(".0M", "M")
             .replace(".0k", "k")
        )

    return FuncFormatter(_fmt)


def format_axis(
    ax,
    *,
    xlabel=None,
    ylabel=None,
    compact_ticks=(),
):
    if xlabel is not None:
        ax.set_xlabel(xlabel)

    if ylabel is not None:
        ax.set_ylabel(ylabel)

    fmt = _compact_formatter()

    if "x" in compact_ticks:
        ax.xaxis.set_major_formatter(fmt)

    if "y" in compact_ticks:
        ax.yaxis.set_major_formatter(fmt)

    return ax


# ============================================
# Joint scatter with KDE marginals
# ============================================

def safe_pearsonr(x, y):
    x = np.asarray(x, dtype=float)
    y = np.asarray(y, dtype=float)

    mask = np.isfinite(x) & np.isfinite(y)
    x = x[mask]
    y = y[mask]

    if len(x) < 2:
        return np.nan, np.nan

    if np.std(x) == 0 or np.std(y) == 0:
        return np.nan, np.nan

    return stats.pearsonr(x, y)


def safe_spearmanr(x, y):
    x = np.asarray(x, dtype=float)
    y = np.asarray(y, dtype=float)

    mask = np.isfinite(x) & np.isfinite(y)
    x = x[mask]
    y = y[mask]

    if len(x) < 2:
        return np.nan, np.nan

    if np.std(x) == 0 or np.std(y) == 0:
        return np.nan, np.nan

    return stats.spearmanr(x, y)

def _kde_1d(values, lo, hi, num=256):
    values = np.asarray(values, dtype=float)
    values = values[np.isfinite(values)]

    grid = np.linspace(lo, hi, num)

    if len(values) < 2:
        return grid, np.zeros_like(grid)

    try:
        kde = stats.gaussian_kde(values)
        dens = kde(grid)
        dens /= dens.max() if dens.max() > 0 else 1
        return grid, dens

    except Exception:
        return grid, np.zeros_like(grid)


def joint_scatter(
    x,
    y,
    *,
    color=None,
    point_size=18,
    alpha=0.65,
    show_identity=True,
    show_regression=True,
    annotate=True,
    annotate_spearman=True,
    xlabel=None,
    ylabel=None,
    title=None,
    figsize=None,
    w=None,
    h=None,
    dpi=None,
    annotate_fontsize=14,
):
    x = np.asarray(x, dtype=float)
    y = np.asarray(y, dtype=float)

    mask = np.isfinite(x) & np.isfinite(y)
    x = x[mask]
    y = y[mask]

    n = len(x)

    if figsize is not None:
        FW, FH = figsize
    else:
        FW = float(w) if w is not None else _PLOT_CFG["fig_w"]
        FH = float(h) if h is not None else _PLOT_CFG["fig_h"]

    fig = plt.figure(
        figsize=(FW, FH),
        dpi=(dpi or _PLOT_CFG["dpi"]),
    )

    gs = GridSpec(
        2,
        2,
        width_ratios=(4, 1),
        height_ratios=(1, 4),
        hspace=0.05,
        wspace=0.05,
    )

    ax_top = fig.add_subplot(gs[0, 0])
    ax_joint = fig.add_subplot(gs[1, 0], sharex=ax_top)
    ax_right = fig.add_subplot(gs[1, 1], sharey=ax_joint)

    ax_joint.scatter(
        x,
        y,
        s=point_size,
        alpha=alpha,
        edgecolor="none",
        color=color,
    )

    lo = float(np.nanmin([x.min(), y.min()]))
    hi = float(np.nanmax([x.max(), y.max()]))

    pad = 0.05 * (hi - lo if hi > lo else 1.0)

    lo -= pad
    hi += pad

    ax_joint.set_xlim(lo, hi)
    ax_joint.set_ylim(lo, hi)

    if show_identity:
        ax_joint.plot(
            [lo, hi],
            [lo, hi],
            ls="--",
            lw=1.2,
            color="0.65",
            zorder=1,
        )

    if show_regression and n >= 2 and np.std(x) > 0 and np.std(y) > 0:
        slope, intercept = np.polyfit(x, y, 1)

        ax_joint.plot(
            [lo, hi],
            slope * np.array([lo, hi]) + intercept,
            color="black",
            lw=1.5,
            zorder=2,
        )

    format_axis(
        ax_joint,
        xlabel=xlabel,
        ylabel=ylabel,
        compact_ticks=(),
    )

    if title:
        ax_joint.set_title(title)

    if annotate and n >= 2 and np.std(x) > 0 and np.std(y) > 0:
        rp, _ = safe_pearsonr(x, y)
        rs, _ = safe_spearmanr(x, y)

        txt = rf"$r_p = {rp:.2f}$"

        if annotate_spearman:
            txt += "\n" + rf"$r_s = {rs:.2f}$"

        txt += f"\n$n = {n}$"

        ax_joint.text(
            0.04,
            0.96,
            txt,
            transform=ax_joint.transAxes,
            ha="left",
            va="top",
            fontsize=annotate_fontsize,
        )

    gx, dx = _kde_1d(x, lo, hi)
    gy, dy = _kde_1d(y, lo, hi)

    ax_top.plot(gx, dx, lw=2, color=color)
    ax_top.axis("off")

    ax_right.plot(dy, gy, lw=2, color=color)
    ax_right.axis("off")

    plt.tight_layout()

    return fig, (ax_joint, ax_top, ax_right)


set_plot_style()

# ============================================
# Plot helper functions
# ============================================

def species_palette():
    return [
        SPECIES_INFO["AT21"]["color"],
        SPECIES_INFO["NB21"]["color"],
        SPECIES_INFO["OS21"]["color"],
    ]


def outside_legend(
    ax,
    *,
    title="Species",
    n_items=3,
    x=1.02,
    y=1.00,
):
    handles, labels = ax.get_legend_handles_labels()

    ax.legend(
        handles[:n_items],
        labels[:n_items],
        title=title,
        frameon=False,
        loc="upper left",
        bbox_to_anchor=(x, y),
        borderaxespad=0,
    )

    return ax

# %%
# ============================================
# Feature annotation helpers
# ============================================

def feature_region(feature):

    if feature.startswith("5'UTR."):
        return "5'UTR"

    if feature.startswith("3'UTR."):
        return "3'UTR"

    if feature.startswith("CDS."):
        return "CDS"

    return "mRNA"


def feature_type(col):

    if col.endswith(".Length"):
        return "Length"

    if (
        ".uAUG" in col
        or ".uORF" in col
        or ".dAUG" in col
        or ".dORF" in col
    ):
        return "ORF_nonCDS"

    if col.endswith(".MFE"):
        return "RNA_structure_MFE"

    if ".wobble_pct_" in col:
        return "Wobble"

    if ".aa_pct_" in col:
        return "Amino_acid_composition"

    if ".dicodon_" in col:
        return "Dicodon"

    if re.search(r"\.[A-Z][a-z]{2}-[AUGC]{3}$", col):
        return "Codon_usage"

    if col.endswith("-freq"):
        return "Nucleotide_kmer_freq"

    return "Other"

# %%
# ============================================
# Load all feature importance tables
# ============================================

RESULT_DIR = Path("../results")

files = [
    ("AT21", "RF",   RESULT_DIR / "rf"   / "AT21.rf.feature_importance.tsv"),
    ("AT21", "LGBM", RESULT_DIR / "lgbm" / "AT21.lgbm.feature_importance.tsv"),

    ("NB21", "RF",   RESULT_DIR / "rf"   / "NB21.rf.feature_importance.tsv"),
    ("NB21", "LGBM", RESULT_DIR / "lgbm" / "NB21.lgbm.feature_importance.tsv"),

    ("OS21", "RF",   RESULT_DIR / "rf"   / "OS21.rf.feature_importance.tsv"),
    ("OS21", "LGBM", RESULT_DIR / "lgbm" / "OS21.lgbm.feature_importance.tsv"),
]

dfs = []

for species, model, path in files:

    df = pd.read_csv(path, sep="\t")

    df["species"] = species
    df["model"] = model

    dfs.append(df)

importance_all = pd.concat(
    dfs,
    ignore_index=True,
)

print(importance_all.shape)

display(
    importance_all.head()
)
# Out:
# (2663, 5)
#   species model  rank       feature  importance
# 0    AT21    RF     1    CDS.G-freq    0.042472
# 1    AT21    RF     2     5'UTR.MFE    0.027173
# 2    AT21    RF     3   CDS.GG-freq    0.018439
# 3    AT21    RF     4  5'UTR.A-freq    0.016365
# 4    AT21    RF     5   CDS.AU-freq    0.015806

# %%
# ============================================
# Choose one model for SSS analysis
# Normalize feature importance within species
# ============================================

TARGET_MODEL = "LGBM"

importance_one = (
    importance_all[
        importance_all["model"] == TARGET_MODEL
    ]
    .copy()
)

# --------------------------------------------
# Feature × species importance matrix
# --------------------------------------------

importance_df = (
    importance_one
    .pivot_table(
        index="feature",
        columns="species",
        values="importance",
        aggfunc="mean",
    )
    .fillna(0)
)

importance_df = importance_df[
    [
        "AT21",
        "NB21",
        "OS21",
    ]
]

print("Raw importance matrix:", importance_df.shape)

display(
    importance_df.head()
)


# --------------------------------------------
# Normalize importance within each species
# --------------------------------------------

importance_norm_df = (
    importance_df
    .div(
        importance_df.sum(axis=0),
        axis=1,
    )
)

print("\nNormalized column sums:")

display(
    importance_norm_df.sum(axis=0)
)

display(
    importance_norm_df.head()
)
# Out:
# Raw importance matrix: (449, 3)
# species         AT21  NB21  OS21
# feature
# 3'UTR.A-freq     6.0   5.0  16.0
# 3'UTR.AA-freq   14.0   4.0  16.0
# 3'UTR.AAA-freq   3.0   9.0  10.0
# 3'UTR.AAC-freq  14.0   5.0  10.0
# 3'UTR.AAG-freq  11.0   9.0   6.0
# Normalized column sums:
# species
# AT21    1.0
# NB21    1.0
# OS21    1.0
# dtype: float64
# species             AT21      NB21      OS21
# feature
# 3'UTR.A-freq    0.001579  0.001759  0.003800
# 3'UTR.AA-freq   0.003684  0.001407  0.003800
# 3'UTR.AAA-freq  0.000789  0.003166  0.002375
# 3'UTR.AAC-freq  0.003684  0.001759  0.002375
# 3'UTR.AAG-freq  0.002895  0.003166  0.001425

# %%
# ============================================
# Species Specificity Score (SSS)
# General version for one ML model
# ============================================

def compute_sss(
    importance_df,
):

    AT = importance_df["AT21"]
    NB = importance_df["NB21"]
    OS = importance_df["OS21"]

    sss_df = pd.DataFrame(
        index=importance_df.index
    )

    # ----------------------------------------
    # Species Specificity Score
    # ----------------------------------------

    sss_df["AT_SSS"] = np.sqrt(
        (AT - NB) ** 2
        +
        (AT - OS) ** 2
    )

    sss_df["NB_SSS"] = np.sqrt(
        (NB - AT) ** 2
        +
        (NB - OS) ** 2
    )

    sss_df["OS_SSS"] = np.sqrt(
        (OS - AT) ** 2
        +
        (OS - NB) ** 2
    )

    # ----------------------------------------
    # Delta = direction only
    # ----------------------------------------

    sss_df["AT_Delta"] = (
        AT - (NB + OS) / 2
    )

    sss_df["NB_Delta"] = (
        NB - (AT + OS) / 2
    )

    sss_df["OS_Delta"] = (
        OS - (AT + NB) / 2
    )

    # ----------------------------------------
    # Annotation
    # ----------------------------------------

    sss_df["Feature"] = sss_df.index

    sss_df["Feature_type"] = (
        sss_df["Feature"]
        .apply(feature_type)
    )

    sss_df["Region"] = (
        sss_df["Feature"]
        .apply(feature_region)
    )

    return sss_df


sss_df = compute_sss(
    importance_norm_df
)

display(
    sss_df.head()
)
# Out:
#                   AT_SSS    NB_SSS    OS_SSS  AT_Delta  NB_Delta  OS_Delta  \
# feature
# 3'UTR.A-freq    0.002228  0.002049  0.003016 -0.001200 -0.000931  0.002131
# 3'UTR.AA-freq   0.002280  0.003303  0.002395  0.001081 -0.002335  0.001254
# 3'UTR.AAA-freq  0.002856  0.002504  0.001772 -0.001981  0.001584  0.000397
# 3'UTR.AAC-freq  0.002329  0.002022  0.001447  0.001617 -0.001271 -0.000347
# 3'UTR.AAG-freq  0.001495  0.001762  0.002278  0.000599  0.001006 -0.001605
#
#                        Feature          Feature_type Region
# feature
# 3'UTR.A-freq      3'UTR.A-freq  Nucleotide_kmer_freq  3'UTR
# 3'UTR.AA-freq    3'UTR.AA-freq  Nucleotide_kmer_freq  3'UTR
# 3'UTR.AAA-freq  3'UTR.AAA-freq  Nucleotide_kmer_freq  3'UTR
# 3'UTR.AAC-freq  3'UTR.AAC-freq  Nucleotide_kmer_freq  3'UTR
# 3'UTR.AAG-freq  3'UTR.AAG-freq  Nucleotide_kmer_freq  3'UTR

# %%
# ============================================
# Convert SSS table to long format
# ============================================

def sss_to_long(
    sss_df,
):

    sss_long = (
        sss_df
        .melt(
            id_vars=[
                "Feature",
                "Feature_type",
                "Region",
            ],
            value_vars=[
                "AT_SSS",
                "NB_SSS",
                "OS_SSS",
            ],
            var_name="Species",
            value_name="SSS",
        )
    )

    sss_long["Species"] = (
        sss_long["Species"]
        .str.replace(
            "_SSS",
            "",
            regex=False,
        )
    )

    delta_long = (
        sss_df
        .melt(
            id_vars=[
                "Feature",
                "Feature_type",
                "Region",
            ],
            value_vars=[
                "AT_Delta",
                "NB_Delta",
                "OS_Delta",
            ],
            var_name="Species",
            value_name="Delta",
        )
    )

    delta_long["Species"] = (
        delta_long["Species"]
        .str.replace(
            "_Delta",
            "",
            regex=False,
        )
    )

    out = (
        sss_long
        .merge(
            delta_long,
            on=[
                "Feature",
                "Feature_type",
                "Region",
                "Species",
            ],
        )
    )

    out["Enrichment"] = np.where(
        out["Delta"] > 0,
        "Enriched",
        "Depleted",
    )

    return out


sss_long = sss_to_long(
    sss_df
)

display(
    sss_long.head()
)
# Out:
#           Feature          Feature_type Region Species       SSS     Delta  \
# 0    3'UTR.A-freq  Nucleotide_kmer_freq  3'UTR      AT  0.002228 -0.001200
# 1   3'UTR.AA-freq  Nucleotide_kmer_freq  3'UTR      AT  0.002280  0.001081
# 2  3'UTR.AAA-freq  Nucleotide_kmer_freq  3'UTR      AT  0.002856 -0.001981
# 3  3'UTR.AAC-freq  Nucleotide_kmer_freq  3'UTR      AT  0.002329  0.001617
# 4  3'UTR.AAG-freq  Nucleotide_kmer_freq  3'UTR      AT  0.001495  0.000599
#
#   Enrichment
# 0   Depleted
# 1   Enriched
# 2   Depleted
# 3   Enriched
# 4   Enriched

# %%
# ============================================
# Keep informative feature classes
# ============================================

keep_feature_types = [
    "Nucleotide_kmer_freq",
    "Length",
    "RNA_structure_MFE",
    "Codon_usage",
    "Amino_acid_composition",
    "Wobble",
]

sss_keep = (
    sss_long[
        sss_long["Feature_type"]
        .isin(keep_feature_types)
    ]
    .copy()
)

display(
    sss_keep.head()
)
# Out:
#           Feature          Feature_type Region Species       SSS     Delta  \
# 0    3'UTR.A-freq  Nucleotide_kmer_freq  3'UTR      AT  0.002228 -0.001200
# 1   3'UTR.AA-freq  Nucleotide_kmer_freq  3'UTR      AT  0.002280  0.001081
# 2  3'UTR.AAA-freq  Nucleotide_kmer_freq  3'UTR      AT  0.002856 -0.001981
# 3  3'UTR.AAC-freq  Nucleotide_kmer_freq  3'UTR      AT  0.002329  0.001617
# 4  3'UTR.AAG-freq  Nucleotide_kmer_freq  3'UTR      AT  0.001495  0.000599
#
#   Enrichment
# 0   Depleted
# 1   Enriched
# 2   Depleted
# 3   Enriched
# 4   Enriched

# %%
def clean_group_distribution(
    data,
    *,
    x,
    y,
    order,
    ax,
    xlabel,
    ylabel,
):

    palette = {
        "AT": SPECIES_INFO["AT21"]["color"],
        "NB": SPECIES_INFO["NB21"]["color"],
        "OS": SPECIES_INFO["OS21"]["color"],
    }

    species_order = ["AT", "NB", "OS"]

    offsets = {
        "AT": -0.22,
        "NB":  0.00,
        "OS":  0.22,
    }

    rng = np.random.default_rng(0)

    # ====================================================
    # First draw ALL boxplots
    # ====================================================

    for i, cat in enumerate(order):

        for sp in species_order:

            vals = data.loc[
                (data[x] == cat) &
                (data["Species"] == sp),
                y
            ].dropna()

            ax.boxplot(
                vals,
                positions=[i + offsets[sp]],
                widths=0.16,
                patch_artist=True,
                manage_ticks=False,
                showfliers=False,

                boxprops=dict(
                    facecolor="none",
                    edgecolor=palette[sp],
                    linewidth=.8,
                ),

                whiskerprops=dict(
                    color=palette[sp],
                    linewidth=.5,
                ),

                capprops=dict(
                    color=palette[sp],
                    linewidth=.5,
                ),

                medianprops=dict(
                    color=palette[sp],
                    linewidth=1,
                ),

                zorder=1,
            )

    # ====================================================
    # Then overlay ALL points
    # ====================================================

    for i, cat in enumerate(order):

        for sp in species_order:

            vals = data.loc[
                (data[x] == cat) &
                (data["Species"] == sp),
                y
            ].dropna()

            xs = rng.normal(
                i + offsets[sp],
                0.03,
                len(vals),
            )

            ax.scatter(
                xs,
                vals,
                s=12,
                color=palette[sp],
                alpha=0.45,
                linewidth=0,
                zorder=3,
            )

    ax.set_xticks(np.arange(len(order)))
    ax.set_xticklabels(order)

    format_axis(
        ax,
        xlabel=xlabel,
        ylabel=ylabel,
    )

    handles = [
        mpl.patches.Patch(
            facecolor="none",
            edgecolor=palette[s],
            linewidth=2,
            label=s,
        )
        for s in species_order
    ]

    ax.legend(
        handles=handles,
        title="Species",
        frameon=False,
        loc="upper left",
        bbox_to_anchor=(1.02, 1),
    )

    return ax

# %%
# ============================================
# SSS distribution
# Feature category
# ============================================

fig, ax = make_fig(
    w=5,
    h=3,
)

clean_group_distribution(
    data=sss_long,
    x="Feature_type",
    y="SSS",
    order=keep_feature_types,
    ax=ax,
    xlabel="Feature category",
    ylabel="SSS",
)

plt.setp(
    ax.get_xticklabels(),
    rotation=30,
    ha="right",
)

plt.tight_layout()
plt.show()

# %%
# ============================================
# SSS distribution
# Region
# ============================================

region_order = [
    "5'UTR",
    "CDS",
    "3'UTR",
    "mRNA",
]

fig, ax = make_fig(
    w=5,
    h=3,
)

clean_group_distribution(
    data=sss_long,
    x="Region",
    y="SSS",
    order=region_order,
    ax=ax,
    xlabel="Region",
    ylabel="SSS",
)

plt.tight_layout()
plt.show()

# %%
# ============================================
# Candidate feature dataframe
# ============================================

importance_long = (
    importance_norm_df
    .reset_index()
    .melt(
        id_vars="feature",
        value_vars=[
            "AT21",
            "NB21",
            "OS21",
        ],
        var_name="Species",
        value_name="Importance",
    )
)

importance_long["Species"] = (
    importance_long["Species"]
    .map({
        "AT21": "AT",
        "NB21": "NB",
        "OS21": "OS",
    })
)

candidate_df = (
    sss_long[
        [
            "Feature",
            "Feature_type",
            "Region",
            "Species",
            "SSS",
        ]
    ]
    .merge(
        importance_long.rename(
            columns={
                "feature": "Feature",
            }
        ),
        on=[
            "Feature",
            "Species",
        ],
        how="left",
        validate="one_to_one",
    )
)

candidate_df["Importance_percentile"] = (
    candidate_df
    .groupby("Species")["Importance"]
    .rank(
        pct=True
    )
)

candidate_df["SSS_percentile"] = (
    candidate_df
    .groupby("Species")["SSS"]
    .rank(
        pct=True
    )
)

display(candidate_df.head())
# Out:
#           Feature          Feature_type Region Species       SSS  Importance  \
# 0    3'UTR.A-freq  Nucleotide_kmer_freq  3'UTR      AT  0.002228    0.001579
# 1   3'UTR.AA-freq  Nucleotide_kmer_freq  3'UTR      AT  0.002280    0.003684
# 2  3'UTR.AAA-freq  Nucleotide_kmer_freq  3'UTR      AT  0.002856    0.000789
# 3  3'UTR.AAC-freq  Nucleotide_kmer_freq  3'UTR      AT  0.002329    0.003684
# 4  3'UTR.AAG-freq  Nucleotide_kmer_freq  3'UTR      AT  0.001495    0.002895
#
#    Importance_percentile  SSS_percentile
# 0               0.359688        0.659243
# 1               0.863029        0.672606
# 2               0.138085        0.781737
# 3               0.863029        0.689310
# 4               0.743875        0.440980

# %%
candidate_df.describe()
# Out:
#                SSS   Importance  Importance_percentile  SSS_percentile
# count  1347.000000  1347.000000            1347.000000     1347.000000
# mean      0.002048     0.002227               0.501114        0.501114
# std       0.001658     0.001713               0.288082        0.288781
# min       0.000078     0.000000               0.011136        0.002227
# 25%       0.000960     0.001055               0.273942        0.251670
# 50%       0.001646     0.001900               0.500000        0.501114
# 75%       0.002716     0.002895               0.743875        0.750557
# max       0.019007     0.020753               1.000000        1.000000

# %%
print(candidate_df.groupby("Species")[
    [
        "Importance",
        "SSS",
        "Importance_percentile",
        "SSS_percentile",
    ]
].describe())
# Out:
#         Importance                                                         \
#              count      mean       std  min       25%       50%       75%
# Species
# AT           449.0  0.002227  0.001384  0.0  0.001316  0.002105  0.002895
# NB           449.0  0.002227  0.001991  0.0  0.001055  0.001759  0.002814
# OS           449.0  0.002227  0.001714  0.0  0.000950  0.002137  0.002850
#
#                      SSS            ... Importance_percentile       \
#               max  count      mean  ...                   75%  max
# Species                             ...
# AT       0.007632  449.0  0.002045  ...              0.743875  1.0
# NB       0.020753  449.0  0.002086  ...              0.740535  1.0
# OS       0.015911  449.0  0.002013  ...              0.728285  1.0
#
#         SSS_percentile                                                   \
#                  count      mean       std       min      25%       50%
# Species
# ...

# %%
# ============================================
# Raw metric quantiles by species
# ============================================

candidate_df.groupby("Species")[
    [
        "Importance",
        "SSS",
    ]
].quantile(
    [0.75, 0.80, 0.85, 0.90, 0.95]
)
# Out:
#               Importance       SSS
# Species
# AT      0.75    0.002895  0.002690
#         0.80    0.003158  0.002960
#         0.85    0.003421  0.003308
#         0.90    0.004000  0.004010
#         0.95    0.004737  0.004784
# NB      0.75    0.002814  0.002717
#         0.80    0.003166  0.003107
#         0.85    0.003869  0.003553
#         0.90    0.004573  0.004065
#         0.95    0.005839  0.004960
# OS      0.75    0.002850  0.002754
#         0.80    0.003325  0.002962
#         0.85    0.003562  0.003185
#         0.90    0.004275  0.003727
#         0.95    0.005224  0.004652

# %%
# ============================================
# Candidate threshold sensitivity
# Importance percentile × SSS percentile
# ============================================

importance_cutoffs = [
    0.75,
    0.80,
    0.85,
    0.90,
    0.95,
]

sss_cutoffs = [
    0.75,
    0.80,
    0.85,
    0.90,
    0.95,
]

rows = []

for importance_cutoff in importance_cutoffs:

    for sss_cutoff in sss_cutoffs:

        keep = (
            (
                candidate_df["Importance_percentile"]
                >= importance_cutoff
            )
            &
            (
                candidate_df["SSS_percentile"]
                >= sss_cutoff
            )
        )

        temp = candidate_df.loc[keep]

        counts = (
            temp["Species"]
            .value_counts()
            .reindex(
                ["AT", "NB", "OS"],
                fill_value=0,
            )
        )

        rows.append({
            "Importance_cutoff": importance_cutoff,
            "SSS_cutoff": sss_cutoff,
            "AT": int(counts["AT"]),
            "NB": int(counts["NB"]),
            "OS": int(counts["OS"]),
            "Total": len(temp),
        })


candidate_threshold_df = pd.DataFrame(rows)

display(candidate_threshold_df)
# Out:
#     Importance_cutoff  SSS_cutoff  AT  NB  OS  Total
# 0                0.75        0.75  54  54  58    166
# 1                0.75        0.80  44  47  48    139
# 2                0.75        0.85  37  39  38    114
# 3                0.75        0.90  25  30  29     84
# 4                0.75        0.95  15  17  18     50
# 5                0.80        0.75  48  51  54    153
# 6                0.80        0.80  39  46  46    131
# 7                0.80        0.85  34  39  37    110
# 8                0.80        0.90  24  30  29     83
# 9                0.80        0.95  14  17  18     49
# 10               0.85        0.75  46  46  47    139
# 11               0.85        0.80  38  43  42    123
# 12               0.85        0.85  33  37  36    106
# 13               0.85        0.90  24  29  28     81
# 14               0.85        0.95  14  16  17     47
# 15               0.90        0.75  35  38  32    105
# 16               0.90        0.80  29  37  29     95
# ...

# %%
# ============================================
# Total candidate count matrix
# ============================================

candidate_count_matrix = (
    candidate_threshold_df
    .pivot(
        index="SSS_cutoff",
        columns="Importance_cutoff",
        values="Total",
    )
)

display(candidate_count_matrix)
# Out:
# Importance_cutoff  0.75  0.80  0.85  0.90  0.95
# SSS_cutoff
# 0.75                166   153   139   105    59
# 0.80                139   131   123    95    58
# 0.85                114   110   106    85    55
# 0.90                 84    83    81    70    46
# 0.95                 50    49    47    42    33

# %%
# ============================================
# Candidate count matrices by species
# ============================================

for species in [
    "AT",
    "NB",
    "OS",
]:

    print("=" * 60)
    print(species)

    species_matrix = (
        candidate_threshold_df
        .pivot(
            index="SSS_cutoff",
            columns="Importance_cutoff",
            values=species,
        )
    )

    display(species_matrix)
# Out:
# ...
# AT
# Importance_cutoff  0.75  0.80  0.85  0.90  0.95
# SSS_cutoff
# 0.75                 54    48    46    35    19
# 0.80                 44    39    38    29    18
# 0.85                 37    34    33    24    16
# 0.90                 25    24    24    19    12
# 0.95                 15    14    14    11     9
# ...
# NB
# Importance_cutoff  0.75  0.80  0.85  0.90  0.95
# SSS_cutoff
# 0.75                 54    51    46    38    22
# 0.80                 47    46    43    37    22
# 0.85                 39    39    37    34    22
# 0.90                 30    30    29    28    20
# 0.95                 17    17    16    16    14
# ...
# OS
# Importance_cutoff  0.75  0.80  0.85  0.90  0.95
# SSS_cutoff
# 0.75                 58    54    47    32    18
# 0.80                 48    46    42    29    18
# 0.85                 38    37    36    27    17
# 0.90                 29    29    28    23    14
# 0.95                 18    18    17    15    10

# %%
# ============================================
# Comprehensive species-specific candidate table
# Keep all LGBM importance features
# ============================================

IMPORTANCE_CUTOFF = 0.90
SSS_CUTOFF = 0.90

candidate_all_df = candidate_df.copy()

# --------------------------------------------
# Rename normalized importance explicitly
# --------------------------------------------

candidate_all_df = candidate_all_df.rename(
    columns={
        "Importance": "Importance_normalized",
    }
)


# --------------------------------------------
# Add raw LightGBM importance
# --------------------------------------------

importance_raw_long = (
    importance_df
    .reset_index()
    .melt(
        id_vars="feature",
        value_vars=[
            "AT21",
            "NB21",
            "OS21",
        ],
        var_name="Species",
        value_name="Importance_raw",
    )
)

importance_raw_long["Species"] = (
    importance_raw_long["Species"]
    .map({
        "AT21": "AT",
        "NB21": "NB",
        "OS21": "OS",
    })
)

importance_raw_long = (
    importance_raw_long
    .rename(
        columns={
            "feature": "Feature",
        }
    )
)


candidate_all_df = (
    candidate_all_df
    .merge(
        importance_raw_long,
        on=[
            "Feature",
            "Species",
        ],
        how="left",
        validate="one_to_one",
    )
)


# --------------------------------------------
# Candidate flag
# --------------------------------------------

candidate_all_df["Selected"] = (
    (
        candidate_all_df["Importance_percentile"]
        >= IMPORTANCE_CUTOFF
    )
    &
    (
        candidate_all_df["SSS_percentile"]
        >= SSS_CUTOFF
    )
)


# --------------------------------------------
# Organize columns
# --------------------------------------------

candidate_all_df = candidate_all_df[
    [
        "Species",
        "Feature",
        "Region",
        "Feature_type",
        "Importance_raw",
        "Importance_normalized",
        "Importance_percentile",
        "SSS",
        "SSS_percentile",
        "Selected",
    ]
].copy()


# --------------------------------------------
# Sort
# Selected candidates first,
# then species, SSS, importance
# --------------------------------------------

candidate_all_df = (
    candidate_all_df
    .sort_values(
        [
            "Selected",
            "Species",
            "SSS",
            "Importance_normalized",
        ],
        ascending=[
            False,
            True,
            False,
            False,
        ],
    )
    .reset_index(drop=True)
)

display(candidate_all_df.head(30))
# Out:
#    Species         Feature Region            Feature_type  Importance_raw  \
# 0       AT    5'UTR.Length  5'UTR                  Length            21.0
# 1       AT        mRNA.MFE   mRNA       RNA_structure_MFE            19.0
# 2       AT  3'UTR.UAG-freq  3'UTR    Nucleotide_kmer_freq            21.0
# 3       AT    5'UTR.U-freq  5'UTR    Nucleotide_kmer_freq            26.0
# 4       AT    CDS.UAU-freq    CDS    Nucleotide_kmer_freq            17.0
# 5       AT  3'UTR.GAU-freq  3'UTR    Nucleotide_kmer_freq            22.0
# 6       AT   mRNA.AUC-freq   mRNA    Nucleotide_kmer_freq            24.0
# 7       AT    5'UTR.S-freq  5'UTR    Nucleotide_kmer_freq            27.0
# 8       AT    CDS.aa_pct_I    CDS  Amino_acid_composition            16.0
# 9       AT   5'UTR.UA-freq  5'UTR    Nucleotide_kmer_freq            19.0
# 10      AT       5'UTR.MFE  5'UTR       RNA_structure_MFE            25.0
# 11      AT    CDS.AAA-freq    CDS    Nucleotide_kmer_freq            17.0
# ...

# %%
# ============================================
# Candidate summary
# ============================================

candidate_summary_df = (
    candidate_all_df
    .groupby(
        [
            "Species",
            "Selected",
        ]
    )
    .size()
    .unstack(
        fill_value=0
    )
)

display(candidate_summary_df)
# Out:
# Selected  False  True
# Species
# AT          430     19
# NB          421     28
# OS          426     23

# %%
# ============================================
# Save comprehensive candidate table
# ============================================

importance_tag = int(
    IMPORTANCE_CUTOFF * 100
)

sss_tag = int(
    SSS_CUTOFF * 100
)

outfile = (
    RESULT_DIR
    / "lgbm"
    / (
        f"lgbm.species_specific_candidate_table"
        f".importance_p{importance_tag}"
        f".sss_p{sss_tag}.tsv.gz"
    )
)

candidate_all_df.to_csv(
    outfile,
    sep="\t",
    index=False,
    compression="gzip",
)

print(f"Saved: {outfile}")
print(f"Rows: {len(candidate_all_df):,}")
print(f"Selected: {candidate_all_df['Selected'].sum():,}")
# Out:
# Saved: ../results/lgbm/lgbm.species_specific_candidate_table.importance_p90.sss_p90.tsv.gz
# Rows: 1,347
# Selected: 70

# %%
# ============================================
# Candidate threshold sensitivity
# Importance percentile × SSS percentile
# ============================================

cutoffs = np.arange(0.00, 1.00, 0.05)
rows = []

for importance_cutoff in cutoffs:
    for sss_cutoff in cutoffs:
        temp = candidate_df.loc[
            (candidate_df["Importance_percentile"] >= importance_cutoff) &
            (candidate_df["SSS_percentile"] >= sss_cutoff)
        ]

        counts = temp["Species"].value_counts().reindex(["AT", "NB", "OS"], fill_value=0)

        rows.append({
            "Importance_cutoff": importance_cutoff,
            "SSS_cutoff": sss_cutoff,
            "AT": int(counts["AT"]),
            "NB": int(counts["NB"]),
            "OS": int(counts["OS"]),
            "Total": len(temp),
        })

candidate_threshold_df = pd.DataFrame(rows)

# --------------------------------------------
# Matched threshold path
# Importance cutoff = SSS cutoff
# --------------------------------------------

threshold_path_df = (
    candidate_threshold_df
    .loc[np.isclose(
        candidate_threshold_df["Importance_cutoff"],
        candidate_threshold_df["SSS_cutoff"]
    )]
    .rename(columns={"Importance_cutoff": "Cutoff"})
    .drop(columns="SSS_cutoff")
    .reset_index(drop=True)
)

print("Full threshold grid")
display(candidate_threshold_df)

print("\nMatched threshold path")
display(threshold_path_df)
# Out:
# Full threshold grid
#      Importance_cutoff  SSS_cutoff   AT   NB   OS  Total
# 0                 0.00        0.00  449  449  449   1347
# 1                 0.00        0.05  427  427  427   1281
# 2                 0.00        0.10  405  404  405   1214
# 3                 0.00        0.15  382  382  382   1146
# 4                 0.00        0.20  360  360  360   1080
# ..                 ...         ...  ...  ...  ...    ...
# 395               0.95        0.75   19   22   18     59
# 396               0.95        0.80   18   22   18     58
# 397               0.95        0.85   16   22   17     55
# 398               0.95        0.90   12   20   14     46
# 399               0.95        0.95    9   14   10     33
#
# [400 rows x 6 columns]
# Matched threshold path
#     Cutoff   AT   NB   OS  Total
# 0     0.00  449  449  449   1347
# 1     0.05  407  413  411   1231
# 2     0.10  373  358  373   1104
# 3     0.15  331  338  333   1002
# 4     0.20  313  291  299    903
# ...

# %%
# ============================================
# Threshold sensitivity and feature-set stability
# ============================================

threshold_sets = {}
metric_rows = []

for species in ["AT", "NB", "OS"]:
    previous_set = None

    for cutoff in cutoffs:
        current_set = set(
            candidate_df.loc[
                (candidate_df["Species"] == species) &
                (candidate_df["Importance_percentile"] >= cutoff) &
                (candidate_df["SSS_percentile"] >= cutoff),
                "Feature"
            ]
        )

        threshold_sets[(species, cutoff)] = current_set

        if previous_set is None:
            jaccard = np.nan
            retention = np.nan
            delta_n = np.nan
        else:
            intersection = len(previous_set & current_set)
            union = len(previous_set | current_set)

            jaccard = intersection / union if union else np.nan
            retention = intersection / len(previous_set) if previous_set else np.nan
            delta_n = len(current_set) - len(previous_set)

        metric_rows.append({
            "Species": species,
            "Cutoff": cutoff,
            "N_features": len(current_set),
            "Delta_features": delta_n,
            "Jaccard": jaccard,
            "Retention": retention,
        })

        previous_set = current_set

threshold_metric_df = pd.DataFrame(metric_rows)

print("Threshold sensitivity and stability")
display(threshold_metric_df)
# Out:
# Threshold sensitivity and stability
#    Species  Cutoff  N_features  Delta_features   Jaccard  Retention
# 0       AT    0.00         449             NaN       NaN        NaN
# 1       AT    0.05         407           -42.0  0.906459   0.906459
# 2       AT    0.10         373           -34.0  0.916462   0.916462
# 3       AT    0.15         331           -42.0  0.887399   0.887399
# 4       AT    0.20         313           -18.0  0.945619   0.945619
# 5       AT    0.25         283           -30.0  0.904153   0.904153
# 6       AT    0.30         243           -40.0  0.858657   0.858657
# 7       AT    0.35         226           -17.0  0.930041   0.930041
# 8       AT    0.40         189           -37.0  0.836283   0.836283
# 9       AT    0.45         160           -29.0  0.846561   0.846561
# 10      AT    0.50         151            -9.0  0.943750   0.943750
# 11      AT    0.55         127           -24.0  0.841060   0.841060
# ...

# %%
# ============================================
# Threshold sensitivity
# Full matched-cutoff path
# ============================================

species_order = ["AT", "NB", "OS"]

species_colors = {
    "AT": "#4C78A8",
    "NB": "#F28E2B",
    "OS": "#59A14F",
}

species_markers = {
    "AT": "o",
    "NB": "s",
    "OS": "^",
}

plot_df = threshold_metric_df.copy()

plot_df["Baseline_features"] = (
    plot_df.groupby("Species")["N_features"]
    .transform("first")
)

plot_df["Fraction_remaining"] = (
    plot_df["N_features"] / plot_df["Baseline_features"]
)

fig, axes = plt.subplots(1, 2, figsize=(10, 4), dpi=_PLOT_CFG["dpi"])

for species in species_order:
    temp = plot_df.loc[plot_df["Species"] == species]

    axes[0].plot(
        temp["Cutoff"], temp["N_features"],
        marker=species_markers[species],
        color=species_colors[species],
        lw=1.8, ms=5, label=species,
    )

    axes[1].plot(
        temp["Cutoff"], temp["Fraction_remaining"],
        marker=species_markers[species],
        color=species_colors[species],
        lw=1.8, ms=5, label=species,
    )

format_axis(axes[0], xlabel="Matched percentile cutoff", ylabel="Selected features")
format_axis(axes[1], xlabel="Matched percentile cutoff", ylabel="Fraction of features remaining")

axes[0].set_xticks(np.arange(0, 1.00, 0.10))
axes[1].set_xticks(np.arange(0, 1.00, 0.10))
axes[1].set_ylim(0, 1.05)

axes[1].legend(title="Species", frameon=False)

plt.tight_layout()
plt.show()

# %%
# Out:
# python    = 3.11.15
# pandas    = 2.3.3
# numpy     = 2.4.6
# scipy     = 1.17.1
# sklearn   = 1.9.0
# optuna    = 4.9.0
# lightgbm  = 4.6.0
# ViennaRNA = 2.7.2
# sylib     = 0.3.0.dev0+ae18bb2

# %%
# ============================================
# Export threshold feature sets
# For reduced-model retention analysis
# ============================================

threshold_feature_rows = []

for (species, cutoff), features in threshold_sets.items():
    for feature in sorted(features):
        threshold_feature_rows.append({
            "Species": species,
            "Cutoff": cutoff,
            "Feature": feature,
        })

threshold_feature_df = (
    pd.DataFrame(threshold_feature_rows)
    .sort_values(["Species", "Cutoff", "Feature"])
    .reset_index(drop=True)
)

threshold_feature_file = (
    RESULT_DIR / "lgbm" / "lgbm.retention_feature_sets.tsv.gz"
)

threshold_feature_df.to_csv(
    threshold_feature_file,
    sep="\t",
    index=False,
    compression="gzip",
)

print(f"Saved: {threshold_feature_file}")
print(f"Rows : {len(threshold_feature_df):,}")

display(
    threshold_feature_df
    .groupby(["Species", "Cutoff"])
    .size()
    .rename("N_features")
    .reset_index()
)
# Out:
# Saved: ../results/lgbm/lgbm.retention_feature_sets.tsv.gz
# Rows : 10,842
#    Species  Cutoff  N_features
# 0       AT    0.00         449
# 1       AT    0.05         407
# 2       AT    0.10         373
# 3       AT    0.15         331
# 4       AT    0.20         313
# 5       AT    0.25         283
# 6       AT    0.30         243
# 7       AT    0.35         226
# 8       AT    0.40         189
# 9       AT    0.45         160
# 10      AT    0.50         151
# 11      AT    0.55         127
# 12      AT    0.60         101
# 13      AT    0.65          93
# 14      AT    0.70          70
# 15      AT    0.75          54
# 16      AT    0.80          39
# 17      AT    0.85          33
# 18      AT    0.90          19
# 19      AT    0.95           9
# 20      NB    0.00         449
# 21      NB    0.05         413
# 22      NB    0.10         358
# 23      NB    0.15         338
# 24      NB    0.20         291
# 25      NB    0.25         273
# 26      NB    0.30         221
# ...
