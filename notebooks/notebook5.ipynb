# %%
# =========================
# Standard library imports
# =========================
import sys
import os
import io
import gzip
from pathlib import Path
import math
import json
import pickle
import logging
import random
import subprocess
import warnings
import collections
import itertools
import re
from IPython.display import display

warnings.filterwarnings("ignore")


# =========================
# Numeric / stats
# =========================
import numpy as np
import pandas as pd
from scipy import sparse
from scipy import stats
from scipy.stats import rankdata
from scipy import __version__ as scipy_version


# =========================
# Plotting / visualization
# =========================
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter, FormatStrFormatter, MaxNLocator
from matplotlib.colors import LinearSegmentedColormap
from matplotlib.gridspec import GridSpec
from matplotlib.patches import Patch
import seaborn as sns


# =========================
# scikit-learn
# =========================
from sklearn import model_selection, metrics
from sklearn.model_selection import (
    train_test_split,
    GroupShuffleSplit,
    KFold,
    GroupKFold,
    cross_val_score,
)
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.compose import TransformedTargetRegressor
from sklearn.preprocessing import StandardScaler, PowerTransformer
from sklearn.linear_model import LassoCV
from sklearn.ensemble import RandomForestRegressor, HistGradientBoostingRegressor
from sklearn.neighbors import LocalOutlierFactor
from sklearn.inspection import permutation_importance
from sklearn.metrics import (
    r2_score,
    mean_squared_error,
    mean_absolute_error,
)
from sklearn import __version__ as sklearn_version


# =========================
# Optimization / AutoML
# =========================
import optuna


# =========================
# LightGBM
# =========================
try:
    import lightgbm as lgb
    from lightgbm import LGBMRegressor
    _HAS_LGBM = True
except Exception as e:
    _HAS_LGBM = False
    raise RuntimeError(
        "LightGBM not installed. Please install it with `pip install lightgbm`."
    ) from e


# =========================
# RNA structure (ViennaRNA)
# =========================
import RNA


# =========================
# UpSet plots
# =========================
try:
    from upsetplot import UpSet, from_memberships
except Exception:
    _ = subprocess.run(
        [sys.executable, "-m", "pip", "install", "-q", "upsetplot"],
        check=False,
    )
    from upsetplot import UpSet, from_memberships


# =========================
# Model explanation
# =========================
import shap


# =========================
# User-provided utilities
# =========================
import sylib  


# =========================
# Version info
# =========================
print(f"python    = {sys.version_info[0]}.{sys.version_info[1]}.{sys.version_info[2]}")
print(f"pandas    = {pd.__version__}")
print(f"numpy     = {np.__version__}")
print(f"scipy     = {scipy_version}")
print(f"optuna    = {optuna.__version__}")
print(f"sklearn   = {sklearn_version}")
print(f"ViennaRNA = {RNA.__version__}")
print(f"lightgbm  = {lgb.__version__}")
print(f"sylib     = {sylib.__version__}")


# =========================
# Progress bar & logging
# =========================
# progress bar from sylib
progress_bar = sylib.utils.ProgressBar()

# reset handlers then configure logging
logging.root.handlers = []
stream_handler = logging.StreamHandler(sys.stderr)
logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s %(levelname)8s: %(message)s",
    handlers=[stream_handler],
)
logger = logging.getLogger(__name__)

# make matplotlib quieter
logging.getLogger("matplotlib").setLevel(logging.WARNING)
# Out:
# python    = 3.11.15
# pandas    = 2.3.3
# numpy     = 2.4.6
# scipy     = 1.17.1
# optuna    = 4.9.0
# sklearn   = 1.9.0
# ViennaRNA = 2.7.2
# lightgbm  = 4.6.0
# sylib     = 0.3.0.dev0+ae18bb2

# %%
# ============================================
# Global plotting configuration
# ============================================

_PLOT_CFG = {
    "fig_w": 6.0,
    "fig_h": 6.0,
    "dpi": 300,
}


SPECIES_INFO = {
    "AT21": {
        "label": "AT",
        "short": "AT21",
        "color": "#664D0AFF",
        "marker": "o",
    },
    "NB21": {
        "label": "NB",
        "short": "NB21",
        "color": "#7e3131",
        "marker": "^",
    },
    "OS21": {
        "label": "OS",
        "short": "OS21",
        "color": "#13563f",
        "marker": "s",
    },
}

def set_plot_style(
    *,
    base_fontsize=10,
    title_fontsize=12,
    label_fontsize=10,
    tick_fontsize=9,
    legend_fontsize=10,
    dpi=300,
    axes_linewidth=1.2,
    spines_top=True,
    spines_right=True,
    tick_size_major=6,
    tick_dir="out",
    grid=False,
    fig_w=6.0,
    fig_h=6.0,
):
    sns.set_style("ticks")

    mpl.rcParams.update({
        "font.family": "DejaVu Sans",
        "font.size": base_fontsize,

        "axes.titlesize": title_fontsize,
        "axes.labelsize": label_fontsize,

        "xtick.labelsize": tick_fontsize,
        "ytick.labelsize": tick_fontsize,

        "legend.fontsize": legend_fontsize,

        "figure.dpi": dpi,
        "savefig.dpi": dpi,

        "axes.linewidth": axes_linewidth,
        "axes.spines.top": spines_top,
        "axes.spines.right": spines_right,
        "axes.grid": grid,
        "axes.axisbelow": True,

        "xtick.major.size": tick_size_major,
        "ytick.major.size": tick_size_major,
        "xtick.direction": tick_dir,
        "ytick.direction": tick_dir,

        "legend.frameon": False,

        "savefig.bbox": "tight",
        "savefig.transparent": False,
        "figure.autolayout": False,
    })

    _PLOT_CFG.update({
        "fig_w": fig_w,
        "fig_h": fig_h,
        "dpi": dpi,
    })


def make_fig(w=None, h=None, dpi=None):
    W = float(w) if w is not None else _PLOT_CFG["fig_w"]
    H = float(h) if h is not None else _PLOT_CFG["fig_h"]
    D = dpi if dpi is not None else _PLOT_CFG["dpi"]

    fig, ax = plt.subplots(
        figsize=(W, H),
        dpi=D,
    )

    return fig, ax


def _compact_formatter():
    def _fmt(x, _pos=None):
        axx = abs(x)

        if axx >= 1e9:
            s = f"{x / 1e9:.1f}B"
        elif axx >= 1e6:
            s = f"{x / 1e6:.1f}M"
        elif axx >= 1e3:
            s = f"{x / 1e3:.1f}k"
        else:
            s = f"{x:.2g}"

        return (
            s.replace(".0B", "B")
             .replace(".0M", "M")
             .replace(".0k", "k")
        )

    return FuncFormatter(_fmt)


def format_axis(
    ax,
    *,
    xlabel=None,
    ylabel=None,
    compact_ticks=(),
):
    if xlabel is not None:
        ax.set_xlabel(xlabel)

    if ylabel is not None:
        ax.set_ylabel(ylabel)

    fmt = _compact_formatter()

    if "x" in compact_ticks:
        ax.xaxis.set_major_formatter(fmt)

    if "y" in compact_ticks:
        ax.yaxis.set_major_formatter(fmt)

    return ax


# ============================================
# Joint scatter with KDE marginals
# ============================================

def safe_pearsonr(x, y):
    x = np.asarray(x, dtype=float)
    y = np.asarray(y, dtype=float)

    mask = np.isfinite(x) & np.isfinite(y)
    x = x[mask]
    y = y[mask]

    if len(x) < 2:
        return np.nan, np.nan

    if np.std(x) == 0 or np.std(y) == 0:
        return np.nan, np.nan

    return stats.pearsonr(x, y)


def safe_spearmanr(x, y):
    x = np.asarray(x, dtype=float)
    y = np.asarray(y, dtype=float)

    mask = np.isfinite(x) & np.isfinite(y)
    x = x[mask]
    y = y[mask]

    if len(x) < 2:
        return np.nan, np.nan

    if np.std(x) == 0 or np.std(y) == 0:
        return np.nan, np.nan

    return stats.spearmanr(x, y)

def _kde_1d(values, lo, hi, num=256):
    values = np.asarray(values, dtype=float)
    values = values[np.isfinite(values)]

    grid = np.linspace(lo, hi, num)

    if len(values) < 2:
        return grid, np.zeros_like(grid)

    try:
        kde = stats.gaussian_kde(values)
        dens = kde(grid)
        dens /= dens.max() if dens.max() > 0 else 1
        return grid, dens

    except Exception:
        return grid, np.zeros_like(grid)


def joint_scatter(
    x,
    y,
    *,
    color=None,
    point_size=18,
    alpha=0.65,
    show_identity=True,
    show_regression=True,
    annotate=True,
    annotate_spearman=True,
    xlabel=None,
    ylabel=None,
    title=None,
    figsize=None,
    w=None,
    h=None,
    dpi=None,
    annotate_fontsize=14,
):
    x = np.asarray(x, dtype=float)
    y = np.asarray(y, dtype=float)

    mask = np.isfinite(x) & np.isfinite(y)
    x = x[mask]
    y = y[mask]

    n = len(x)

    if figsize is not None:
        FW, FH = figsize
    else:
        FW = float(w) if w is not None else _PLOT_CFG["fig_w"]
        FH = float(h) if h is not None else _PLOT_CFG["fig_h"]

    fig = plt.figure(
        figsize=(FW, FH),
        dpi=(dpi or _PLOT_CFG["dpi"]),
    )

    gs = GridSpec(
        2,
        2,
        width_ratios=(4, 1),
        height_ratios=(1, 4),
        hspace=0.05,
        wspace=0.05,
    )

    ax_top = fig.add_subplot(gs[0, 0])
    ax_joint = fig.add_subplot(gs[1, 0], sharex=ax_top)
    ax_right = fig.add_subplot(gs[1, 1], sharey=ax_joint)

    ax_joint.scatter(
        x,
        y,
        s=point_size,
        alpha=alpha,
        edgecolor="none",
        color=color,
    )

    lo = float(np.nanmin([x.min(), y.min()]))
    hi = float(np.nanmax([x.max(), y.max()]))

    pad = 0.05 * (hi - lo if hi > lo else 1.0)

    lo -= pad
    hi += pad

    ax_joint.set_xlim(lo, hi)
    ax_joint.set_ylim(lo, hi)

    if show_identity:
        ax_joint.plot(
            [lo, hi],
            [lo, hi],
            ls="--",
            lw=1.2,
            color="0.65",
            zorder=1,
        )

    if show_regression and n >= 2 and np.std(x) > 0 and np.std(y) > 0:
        slope, intercept = np.polyfit(x, y, 1)

        ax_joint.plot(
            [lo, hi],
            slope * np.array([lo, hi]) + intercept,
            color="black",
            lw=1.5,
            zorder=2,
        )

    format_axis(
        ax_joint,
        xlabel=xlabel,
        ylabel=ylabel,
        compact_ticks=(),
    )

    if title:
        ax_joint.set_title(title)

    if annotate and n >= 2 and np.std(x) > 0 and np.std(y) > 0:
        rp, _ = safe_pearsonr(x, y)
        rs, _ = safe_spearmanr(x, y)

        txt = rf"$r_p = {rp:.2f}$"

        if annotate_spearman:
            txt += "\n" + rf"$r_s = {rs:.2f}$"

        txt += f"\n$n = {n}$"

        ax_joint.text(
            0.04,
            0.96,
            txt,
            transform=ax_joint.transAxes,
            ha="left",
            va="top",
            fontsize=annotate_fontsize,
        )

    gx, dx = _kde_1d(x, lo, hi)
    gy, dy = _kde_1d(y, lo, hi)

    ax_top.plot(gx, dx, lw=2, color=color)
    ax_top.axis("off")

    ax_right.plot(dy, gy, lw=2, color=color)
    ax_right.axis("off")

    plt.tight_layout()

    return fig, (ax_joint, ax_top, ax_right)


set_plot_style()

# ============================================
# Plot helper functions
# ============================================

def species_palette():
    return [
        SPECIES_INFO["AT21"]["color"],
        SPECIES_INFO["NB21"]["color"],
        SPECIES_INFO["OS21"]["color"],
    ]


def outside_legend(
    ax,
    *,
    title="Species",
    n_items=3,
    x=1.02,
    y=1.00,
):
    handles, labels = ax.get_legend_handles_labels()

    ax.legend(
        handles[:n_items],
        labels[:n_items],
        title=title,
        frameon=False,
        loc="upper left",
        bbox_to_anchor=(x, y),
        borderaxespad=0,
    )

    return ax

# %%
# ============================================
# 01. Load locked selected-feature dataset
# ============================================

RESULT_DIR = Path("/mnt/d/Ibnu/Programming/data/regression/results/lgbm")
SPECIES_KEYS = ["AT21", "NB21", "OS21"]
SPECIES_ORDER = ["AT", "NB", "OS"]

# Locked FI + SSS selection table
candidate_all_df = pd.read_csv(
    RESULT_DIR / "lgbm.species_specific_candidate_table.importance_p90.sss_p90.tsv.gz",
    sep="\t",
)

candidate_selected_df = (
    candidate_all_df
    .loc[candidate_all_df["Selected"]]
    .copy()
    .reset_index(drop=True)
)

candidate_features = sorted(candidate_selected_df["Feature"].unique())

feature_metadata_df = (
    candidate_selected_df[["Feature", "Region", "Feature_type"]]
    .drop_duplicates()
    .sort_values("Feature")
    .reset_index(drop=True)
)

# Raw biological data for the 61-feature union
raw_rows = []

for species_key in SPECIES_KEYS:
    species = SPECIES_INFO[species_key]["label"]

    with gzip.open(
        RESULT_DIR / f"{species_key}.lgbm.data_bundle.pkl.gz",
        "rb",
    ) as f:
        bundle = pickle.load(f)

    assert bundle["species"] == species_key
    assert set(candidate_features).issubset(bundle["feature_names"])

    metadata = pd.concat(
        [bundle["train_metadata"], bundle["test_metadata"]]
    )

    x_raw = pd.concat(
        [bundle["x_train_raw"], bundle["x_test_raw"]]
    )[candidate_features]

    assert metadata.index.equals(x_raw.index)

    temp = pd.concat([metadata, x_raw], axis=1)
    temp.insert(0, "Species", species)

    raw_rows.append(temp)

candidate_master_df = pd.concat(
    raw_rows,
    ignore_index=True,
)

# Sanity checks
selected_count_df = (
    candidate_selected_df
    .groupby("Species")
    .size()
    .reindex(SPECIES_ORDER)
    .rename("N_selected")
    .reset_index()
)

assert selected_count_df.set_index("Species")["N_selected"].to_dict() == {
    "AT": 19,
    "NB": 28,
    "OS": 23,
}

assert len(candidate_features) == 61
assert feature_metadata_df["Feature"].is_unique
assert set(feature_metadata_df["Feature"]) == set(candidate_features)
assert candidate_master_df[candidate_features].isna().sum().sum() == 0

print("Locked selected-feature dataset")
print("--------------------------------")
print("Selected rows   :", len(candidate_selected_df))
print("Unique features :", len(candidate_features))
print("Raw data shape  :", candidate_master_df.shape)

display(selected_count_df)
display(feature_metadata_df.head())
# Out:
# Locked selected-feature dataset
# --------------------------------
# Selected rows   : 70
# Unique features : 61
# Raw data shape  : (18059, 69)
#   Species  N_selected
# 0      AT          19
# 1      NB          28
# 2      OS          23
#           Feature Region          Feature_type
# 0  3'UTR.ACA-freq  3'UTR  Nucleotide_kmer_freq
# 1   3'UTR.AG-freq  3'UTR  Nucleotide_kmer_freq
# 2  3'UTR.AUC-freq  3'UTR  Nucleotide_kmer_freq
# 3    3'UTR.G-freq  3'UTR  Nucleotide_kmer_freq
# 4  3'UTR.GAU-freq  3'UTR  Nucleotide_kmer_freq

# %%
# ============================================
# 02. Predictive selection membership
# SSF / PSF / MSF
# ============================================

membership_df = (
    candidate_selected_df.assign(Selected=1)
    .pivot_table(index="Feature", columns="Species", values="Selected", aggfunc="max", fill_value=0)
    .reindex(columns=SPECIES_ORDER, fill_value=0).reset_index()
    .merge(feature_metadata_df, on="Feature", how="left", validate="one_to_one")
)

membership_df["N_species"] = membership_df[SPECIES_ORDER].sum(axis=1).astype(int)
membership_df["Selection_class"] = membership_df["N_species"].map({1: "SSF", 2: "PSF", 3: "MSF"})
membership_df["Membership"] = membership_df.apply(
    lambda r: "-".join(sp for sp in SPECIES_ORDER if r[sp] == 1), axis=1
)

membership_df = (
    membership_df[
        ["Feature", "Region", "Feature_type", "AT", "NB", "OS",
         "N_species", "Selection_class", "Membership"]
    ]
    .sort_values(["N_species", "Membership", "Feature"], ascending=[False, True, True])
    .reset_index(drop=True)
)

class_summary_df = (
    membership_df["Selection_class"].value_counts()
    .reindex(["SSF", "PSF", "MSF"], fill_value=0)
    .rename("N_features").rename_axis("Selection_class").reset_index()
)

membership_summary_df = (
    membership_df.groupby(["Selection_class", "Membership"], as_index=False)
    .agg(N_features=("Feature", "size"))
)

assert len(membership_df) == 61
assert membership_df["Feature"].is_unique
assert membership_df["N_species"].between(1, 3).all()

print("Predictive selection membership")
display(class_summary_df)
display(membership_summary_df)
display(membership_df)
# Out:
# Predictive selection membership
#   Selection_class  N_features
# 0             SSF          53
# 1             PSF           7
# 2             MSF           1
#   Selection_class Membership  N_features
# 0             MSF   AT-NB-OS           1
# 1             PSF      AT-NB           2
# 2             PSF      AT-OS           1
# 3             PSF      NB-OS           4
# 4             SSF         AT          15
# 5             SSF         NB          21
# 6             SSF         OS          17
#            Feature Region          Feature_type  AT  NB  OS  N_species  \
# 0     5'UTR.Length  5'UTR                Length   1   1   1          3
# 1        5'UTR.MFE  5'UTR     RNA_structure_MFE   1   1   0          2
# 2         mRNA.MFE   mRNA     RNA_structure_MFE   1   1   0          2
# 3     5'UTR.U-freq  5'UTR  Nucleotide_kmer_freq   1   0   1          2
# 4   5'UTR.UAU-freq  5'UTR  Nucleotide_kmer_freq   0   1   1          2
# ..             ...    ...                   ...  ..  ..  ..        ...
# 56   mRNA.AAA-freq   mRNA  Nucleotide_kmer_freq   0   0   1          1
# 57     mRNA.K-freq   mRNA  Nucleotide_kmer_freq   0   0   1          1
# 58     mRNA.U-freq   mRNA  Nucleotide_kmer_freq   0   0   1          1
# 59    mRNA.UC-freq   mRNA  Nucleotide_kmer_freq   0   0   1          1
# 60     mRNA.Y-freq   mRNA  Nucleotide_kmer_freq   0   0   1          1
#
#    Selection_class Membership
# 0              MSF   AT-NB-OS
# 1              PSF      AT-NB
# 2              PSF      AT-NB
# 3              PSF      AT-OS
# 4              PSF      NB-OS
# ..             ...        ...
# 56             SSF         OS
# 57             SSF         OS
# 58             SSF         OS
# 59             SSF         OS
# 60             SSF         OS
#
# [61 rows x 9 columns]

# %%
# ============================================
# 03. Predictive vocabulary composition
# Region + feature type
# ============================================

region_order = ["5'UTR", "CDS", "3'UTR", "mRNA"]
type_order = ["Length", "RNA_structure_MFE", "Amino_acid_composition", "Nucleotide_kmer_freq"]
class_order = ["SSF", "PSF", "MSF"]

region_summary_df = (
    membership_df.groupby(["Selection_class", "Region"], as_index=False)
    .agg(N_features=("Feature", "size"))
)
region_summary_df["Percent"] = (
    100 * region_summary_df["N_features"]
    / region_summary_df.groupby("Selection_class")["N_features"].transform("sum")
)

type_summary_df = (
    membership_df.groupby(["Selection_class", "Feature_type"], as_index=False)
    .agg(N_features=("Feature", "size"))
)
type_summary_df["Percent"] = (
    100 * type_summary_df["N_features"]
    / type_summary_df.groupby("Selection_class")["N_features"].transform("sum")
)

overall_summary_df = pd.DataFrame({
    "N_features": [len(membership_df)],
    "N_SSF": [(membership_df["Selection_class"] == "SSF").sum()],
    "N_PSF": [(membership_df["Selection_class"] == "PSF").sum()],
    "N_MSF": [(membership_df["Selection_class"] == "MSF").sum()],
})

print("Predictive vocabulary composition")
display(overall_summary_df)
display(region_summary_df.sort_values(["Selection_class", "Region"]))
display(type_summary_df.sort_values(["Selection_class", "Feature_type"]))
# Out:
# Predictive vocabulary composition
#    N_features  N_SSF  N_PSF  N_MSF
# 0          61     53      7      1
#   Selection_class Region  N_features     Percent
# 0             MSF  5'UTR           1  100.000000
# 1             PSF  5'UTR           4   57.142857
# 2             PSF    CDS           1   14.285714
# 3             PSF   mRNA           2   28.571429
# 4             SSF  3'UTR           9   16.981132
# 5             SSF  5'UTR          19   35.849057
# 6             SSF    CDS           8   15.094340
# 7             SSF   mRNA          17   32.075472
#   Selection_class            Feature_type  N_features     Percent
# 0             MSF                  Length           1  100.000000
# 1             PSF                  Length           2   28.571429
# 2             PSF    Nucleotide_kmer_freq           3   42.857143
# 3             PSF       RNA_structure_MFE           2   28.571429
# 4             SSF  Amino_acid_composition           2    3.773585
# 5             SSF                  Length           1    1.886792
# 6             SSF    Nucleotide_kmer_freq          50   94.339623

# %%
# ============================================
# 04. Selected features ranked by FI
# ============================================

ranked_feature_df = (
    candidate_selected_df[
        ["Species", "Feature", "Region", "Feature_type",
         "Importance_normalized", "SSS"]
    ]
    .merge(
        membership_df[["Feature", "Selection_class", "Membership"]],
        on="Feature", how="left", validate="many_to_one"
    )
    .sort_values(["Species", "Importance_normalized"], ascending=[True, False])
    .reset_index(drop=True)
)

ranked_feature_df["FI_rank"] = ranked_feature_df.groupby("Species").cumcount() + 1

ranked_feature_df = ranked_feature_df[
    ["Species", "FI_rank", "Feature", "Region", "Feature_type",
     "Selection_class", "Membership", "Importance_normalized", "SSS"]
]

for species in SPECIES_ORDER:
    d = ranked_feature_df.query("Species == @species").reset_index(drop=True)
    print(f"\n{species}: n = {len(d)}")
    display(d)
# Out:
# AT: n = 19
#    Species  FI_rank         Feature Region            Feature_type  \
# 0       AT        1  5'UTR.CUU-freq  5'UTR    Nucleotide_kmer_freq
# 1       AT        2    5'UTR.S-freq  5'UTR    Nucleotide_kmer_freq
# 2       AT        3    5'UTR.U-freq  5'UTR    Nucleotide_kmer_freq
# 3       AT        4       5'UTR.MFE  5'UTR       RNA_structure_MFE
# 4       AT        5   mRNA.AUC-freq   mRNA    Nucleotide_kmer_freq
# 5       AT        6    5'UTR.G-freq  5'UTR    Nucleotide_kmer_freq
# 6       AT        7  3'UTR.GAU-freq  3'UTR    Nucleotide_kmer_freq
# 7       AT        8    5'UTR.Length  5'UTR                  Length
# 8       AT        9  3'UTR.UAG-freq  3'UTR    Nucleotide_kmer_freq
# 9       AT       10        mRNA.MFE   mRNA       RNA_structure_MFE
# 10      AT       11   5'UTR.UA-freq  5'UTR    Nucleotide_kmer_freq
# 11      AT       12   mRNA.UAG-freq   mRNA    Nucleotide_kmer_freq
# 12      AT       13   mRNA.AUA-freq   mRNA    Nucleotide_kmer_freq
# 13      AT       14  5'UTR.UCA-freq  5'UTR    Nucleotide_kmer_freq
# 14      AT       15     CDS.AU-freq    CDS    Nucleotide_kmer_freq
# 15      AT       16      CDS.U-freq    CDS    Nucleotide_kmer_freq
# 16      AT       17    CDS.UAU-freq    CDS    Nucleotide_kmer_freq
# 17      AT       18    CDS.AAA-freq    CDS    Nucleotide_kmer_freq
# 18      AT       19    CDS.aa_pct_I    CDS  Amino_acid_composition
#
#    Selection_class Membership  Importance_normalized       SSS
# 0              SSF         AT               0.007632  0.004324
# 1              SSF         AT               0.007105  0.005207
# 2              PSF      AT-OS               0.006842  0.006238
# 3              PSF      AT-NB               0.006579  0.004869
# 4              SSF         AT               0.006316  0.005450
# 5              SSF         AT               0.006316  0.004291
# 6              SSF         AT               0.005789  0.005705
# 7              MSF   AT-NB-OS               0.005526  0.010997
# 8              SSF         AT               0.005526  0.006610
# 9              PSF      AT-NB               0.005000  0.008363
# 10             SSF         AT               0.005000  0.004874
# 11             SSF         AT               0.005000  0.004324
# 12             SSF         AT               0.004737  0.004454
# 13             SSF         AT               0.004737  0.004280
# 14             SSF         AT               0.004737  0.004251
# 15             SSF         AT               0.004737  0.004018
# 16             SSF         AT               0.004474  0.005743
# 17             SSF         AT               0.004474  0.004565
# 18             SSF         AT               0.004211  0.004902
# NB: n = 28
#    Species  FI_rank         Feature Region            Feature_type  \
# 0       NB        1     mRNA.Length   mRNA                  Length
# 1       NB        2        mRNA.MFE   mRNA       RNA_structure_MFE
# 2       NB        3       5'UTR.MFE  5'UTR       RNA_structure_MFE
# 3       NB        4    5'UTR.Length  5'UTR                  Length
# 4       NB        5   3'UTR.AG-freq  3'UTR    Nucleotide_kmer_freq
# 5       NB        6   5'UTR.UG-freq  5'UTR    Nucleotide_kmer_freq
# 6       NB        7  5'UTR.CUC-freq  5'UTR    Nucleotide_kmer_freq
# 7       NB        8      CDS.Length    CDS                  Length
# 8       NB        9  5'UTR.UAU-freq  5'UTR    Nucleotide_kmer_freq
# 9       NB       10   5'UTR.CU-freq  5'UTR    Nucleotide_kmer_freq
# 10      NB       11     mRNA.C-freq   mRNA    Nucleotide_kmer_freq
# 11      NB       12   mRNA.CCC-freq   mRNA    Nucleotide_kmer_freq
# 12      NB       13   mRNA.GCG-freq   mRNA    Nucleotide_kmer_freq
# 13      NB       14    mRNA.GU-freq   mRNA    Nucleotide_kmer_freq
# 14      NB       15  5'UTR.AUC-freq  5'UTR    Nucleotide_kmer_freq
# 15      NB       16  5'UTR.ACA-freq  5'UTR    Nucleotide_kmer_freq
# 16      NB       17    mRNA.GC-freq   mRNA    Nucleotide_kmer_freq
# 17      NB       18  5'UTR.UGG-freq  5'UTR    Nucleotide_kmer_freq
# 18      NB       19   mRNA.GCU-freq   mRNA    Nucleotide_kmer_freq
# 19      NB       20  3'UTR.ACA-freq  3'UTR    Nucleotide_kmer_freq
# 20      NB       21    CDS.aa_pct_X    CDS  Amino_acid_composition
# 21      NB       22    CDS.CAC-freq    CDS    Nucleotide_kmer_freq
# 22      NB       23    mRNA.CC-freq   mRNA    Nucleotide_kmer_freq
# 23      NB       24   mRNA.GUA-freq   mRNA    Nucleotide_kmer_freq
# 24      NB       25  3'UTR.AUC-freq  3'UTR    Nucleotide_kmer_freq
# 25      NB       26   5'UTR.UC-freq  5'UTR    Nucleotide_kmer_freq
# 26      NB       27    3'UTR.G-freq  3'UTR    Nucleotide_kmer_freq
# 27      NB       28   mRNA.CUA-freq   mRNA    Nucleotide_kmer_freq
#
#    Selection_class Membership  Importance_normalized       SSS
# 0              PSF      NB-OS               0.020753  0.019007
# 1              PSF      AT-NB               0.013014  0.013132
# 2              PSF      AT-NB               0.010200  0.007771
# 3              MSF   AT-NB-OS               0.009145  0.007673
# 4              SSF         NB               0.008794  0.009082
# 5              SSF         NB               0.008442  0.008929
# 6              SSF         NB               0.008090  0.004804
# 7              PSF      NB-OS               0.007738  0.005380
# 8              PSF      NB-OS               0.007387  0.005869
# 9              SSF         NB               0.007387  0.004173
# 10             SSF         NB               0.007387  0.004087
# 11             SSF         NB               0.006683  0.006995
# 12             SSF         NB               0.006683  0.006286
# 13             SSF         NB               0.006683  0.004973
# 14             SSF         NB               0.006683  0.004941
# 15             SSF         NB               0.006331  0.006693
# 16             SSF         NB               0.006331  0.004579
# 17             SSF         NB               0.005980  0.005626
# 18             SSF         NB               0.005980  0.005133
# 19             SSF         NB               0.005980  0.004666
# 20             SSF         NB               0.005276  0.005716
# 21             SSF         NB               0.005276  0.004816
# 22             SSF         NB               0.005276  0.004525
# 23             SSF         NB               0.005276  0.004525
# 24             SSF         NB               0.005276  0.004104
# 25             PSF      NB-OS               0.004924  0.005304
# 26             SSF         NB               0.004924  0.004418
# 27             SSF         NB               0.004924  0.004135
# OS: n = 23
#    Species  FI_rank         Feature Region          Feature_type  \
# 0       OS        1    5'UTR.Length  5'UTR                Length
# 1       OS        2     mRNA.Length   mRNA                Length
# 2       OS        3    3'UTR.Length  3'UTR                Length
# 3       OS        4   5'UTR.UC-freq  5'UTR  Nucleotide_kmer_freq
# 4       OS        5      CDS.Length    CDS                Length
# 5       OS        6  5'UTR.CCC-freq  5'UTR  Nucleotide_kmer_freq
# 6       OS        7    mRNA.UC-freq   mRNA  Nucleotide_kmer_freq
# 7       OS        8   5'UTR.CC-freq  5'UTR  Nucleotide_kmer_freq
# 8       OS        9     mRNA.Y-freq   mRNA  Nucleotide_kmer_freq
# 9       OS       10  5'UTR.CCG-freq  5'UTR  Nucleotide_kmer_freq
# 10      OS       11   5'UTR.CG-freq  5'UTR  Nucleotide_kmer_freq
# 11      OS       12  5'UTR.UAU-freq  5'UTR  Nucleotide_kmer_freq
# 12      OS       13    CDS.CAA-freq    CDS  Nucleotide_kmer_freq
# 13      OS       14   3'UTR.UC-freq  3'UTR  Nucleotide_kmer_freq
# 14      OS       15   mRNA.AAA-freq   mRNA  Nucleotide_kmer_freq
# 15      OS       16  5'UTR.UCG-freq  5'UTR  Nucleotide_kmer_freq
# 16      OS       17     mRNA.U-freq   mRNA  Nucleotide_kmer_freq
# 17      OS       18     mRNA.K-freq   mRNA  Nucleotide_kmer_freq
# 18      OS       19  3'UTR.GUA-freq  3'UTR  Nucleotide_kmer_freq
# 19      OS       20  5'UTR.AGG-freq  5'UTR  Nucleotide_kmer_freq
# 20      OS       21  5'UTR.UGC-freq  5'UTR  Nucleotide_kmer_freq
# 21      OS       22    5'UTR.U-freq  5'UTR  Nucleotide_kmer_freq
# 22      OS       23  5'UTR.ACU-freq  5'UTR  Nucleotide_kmer_freq
#
#    Selection_class Membership  Importance_normalized       SSS
# 0              MSF   AT-NB-OS               0.015911  0.012394
# 1              PSF      NB-OS               0.011874  0.011902
# 2              SSF         OS               0.009736  0.009053
# 3              PSF      NB-OS               0.008549  0.008327
# 4              PSF      NB-OS               0.008074  0.005716
# 5              SSF         OS               0.006887  0.005413
# 6              SSF         OS               0.006412  0.005394
# 7              SSF         OS               0.006174  0.004200
# 8              SSF         OS               0.005937  0.004440
# 9              SSF         OS               0.005462  0.005614
# 10             SSF         OS               0.005462  0.005100
# 11             PSF      NB-OS               0.005462  0.004100
# 12             SSF         OS               0.005224  0.005293
# 13             SSF         OS               0.005224  0.003737
# 14             SSF         OS               0.004987  0.005020
# 15             SSF         OS               0.004987  0.004765
# 16             SSF         OS               0.004987  0.004765
# 17             SSF         OS               0.004987  0.004327
# 18             SSF         OS               0.004749  0.004868
# 19             SSF         OS               0.004512  0.005262
# 20             SSF         OS               0.004512  0.004456
# 21             PSF      AT-OS               0.004512  0.004169
# 22             SSF         OS               0.004512  0.003797

# %%
# ============================================
# 05. Cross-species predictive overlap
# ============================================

from matplotlib_venn import venn3

counts = membership_df["Membership"].value_counts()
subsets = (
    counts.get("AT", 0), counts.get("NB", 0), counts.get("AT-NB", 0),
    counts.get("OS", 0), counts.get("AT-OS", 0), counts.get("NB-OS", 0),
    counts.get("AT-NB-OS", 0),
)

fig, ax = plt.subplots(figsize=(4, 3), dpi=_PLOT_CFG["dpi"])
venn3(
    subsets=subsets,
    set_labels=("AT", "NB", "OS"),
    set_colors=[SPECIES_INFO[k]["color"] for k in SPECIES_KEYS],
    alpha=0.65, ax=ax,
)
plt.tight_layout()
plt.show()

display(
    membership_df.groupby(["Selection_class", "Membership"], as_index=False)
    .agg(N_features=("Feature", "size"))
)
# Out:
#   Selection_class Membership  N_features
# 0             MSF   AT-NB-OS           1
# 1             PSF      AT-NB           2
# 2             PSF      AT-OS           1
# 3             PSF      NB-OS           4
# 4             SSF         AT          15
# 5             SSF         NB          21
# 6             SSF         OS          17

# %%
# ============================================
# 06. Feature–PR association across species
# Spearman rho + BH-FDR
# ============================================

from statsmodels.stats.multitest import multipletests

rows = []

for species in SPECIES_ORDER:
    d = candidate_master_df.query("Species == @species")

    for feature in candidate_features:
        rho, p = safe_spearmanr(d[feature], d["observed_raw"])
        rows.append({"Species": species, "Feature": feature, "PR_rho": rho, "P_value": p})

feature_pr_df = pd.DataFrame(rows)

feature_pr_df["P_adj"] = (
    feature_pr_df.groupby("Species")["P_value"]
    .transform(lambda x: multipletests(x, method="fdr_bh")[1])
)

feature_pr_df["Significant"] = feature_pr_df["P_adj"] < 0.05

feature_pr_df = (
    feature_pr_df
    .merge(
        membership_df[["Feature", "Region", "Feature_type", "Selection_class", "Membership"]],
        on="Feature", how="left", validate="many_to_one"
    )
    .sort_values(["Species", "PR_rho"], ascending=[True, False])
    .reset_index(drop=True)
)

pr_summary_df = (
    feature_pr_df.groupby("Species", as_index=False)
    .agg(
        N_features=("Feature", "size"),
        N_significant=("Significant", "sum"),
        Median_abs_rho=("PR_rho", lambda x: x.abs().median()),
        Max_abs_rho=("PR_rho", lambda x: x.abs().max()),
    )
)

print("Feature–PR association")
display(pr_summary_df)
display(feature_pr_df)
# Out:
# Feature–PR association
#   Species  N_features  N_significant  Median_abs_rho  Max_abs_rho
# 0      AT          61             48        0.072641     0.206221
# 1      NB          61             45        0.047149     0.455792
# 2      OS          61             44        0.050100     0.219563
#     Species         Feature    PR_rho       P_value         P_adj  \
# 0        AT       5'UTR.MFE  0.171073  6.184128e-48  1.257439e-46
# 1        AT    mRNA.GC-freq  0.094744  1.106133e-15  3.748562e-15
# 2        AT        mRNA.MFE  0.091073  1.332522e-14  4.278097e-14
# 3        AT    CDS.aa_pct_X  0.090525  1.915972e-14  5.312467e-14
# 4        AT  5'UTR.ACA-freq  0.074827  2.543590e-10  5.350310e-10
# ..      ...             ...       ...           ...           ...
# 178      OS   mRNA.CCC-freq -0.133709  1.440430e-23  1.255232e-22
# 179      OS     mRNA.Y-freq -0.160176  3.151925e-33  3.204457e-32
# 180      OS    mRNA.UC-freq -0.175935  7.738956e-40  9.441526e-39
# 181      OS      CDS.Length -0.195089  9.409930e-49  1.913352e-47
# 182      OS     mRNA.Length -0.219563  1.383842e-61  8.441435e-60
#
#      Significant Region            Feature_type Selection_class Membership
# 0           True  5'UTR       RNA_structure_MFE             PSF      AT-NB
# 1           True   mRNA    Nucleotide_kmer_freq             SSF         NB
# 2           True   mRNA       RNA_structure_MFE             PSF      AT-NB
# 3           True    CDS  Amino_acid_composition             SSF         NB
# 4           True  5'UTR    Nucleotide_kmer_freq             SSF         NB
# ..           ...    ...                     ...             ...        ...
# 178         True   mRNA    Nucleotide_kmer_freq             SSF         NB
# 179         True   mRNA    Nucleotide_kmer_freq             SSF         OS
# 180         True   mRNA    Nucleotide_kmer_freq             SSF         OS
# 181         True    CDS                  Length             PSF      NB-OS
# 182         True   mRNA                  Length             PSF      NB-OS
#
# [183 rows x 10 columns]

# %%
# ============================================
# 07. Cross-species PR effect matrix
# 61 features × 3 species
# ============================================

pr_effect_df = (
    feature_pr_df
    .pivot(index="Feature", columns="Species", values="PR_rho")
    .reindex(columns=SPECIES_ORDER)
    .reset_index()
    .merge(
        membership_df[["Feature", "Region", "Feature_type", "Selection_class", "Membership"]],
        on="Feature", how="left", validate="one_to_one"
    )
)

pr_q_df = (
    feature_pr_df
    .pivot(index="Feature", columns="Species", values="P_adj")
    .reindex(columns=SPECIES_ORDER)
    .reset_index()
    .rename(columns={s: f"{s}_q" for s in SPECIES_ORDER})
)

pr_effect_df = (
    pr_effect_df
    .merge(pr_q_df, on="Feature", validate="one_to_one")
    .rename(columns={s: f"{s}_rho" for s in SPECIES_ORDER})
)

pr_effect_df["Max_abs_rho"] = pr_effect_df[
    [f"{s}_rho" for s in SPECIES_ORDER]
].abs().max(axis=1)

pr_effect_df = (
    pr_effect_df
    .sort_values("Max_abs_rho", ascending=False)
    .reset_index(drop=True)
)

assert len(pr_effect_df) == 61
assert pr_effect_df["Feature"].is_unique

display(
    pr_effect_df[
        ["Feature", "Region", "Feature_type", "Selection_class", "Membership",
         "AT_rho", "NB_rho", "OS_rho", "AT_q", "NB_q", "OS_q", "Max_abs_rho"]
    ]
)
# Out:
#            Feature Region            Feature_type Selection_class Membership  \
# 0      mRNA.Length   mRNA                  Length             PSF      NB-OS
# 1         mRNA.MFE   mRNA       RNA_structure_MFE             PSF      AT-NB
# 2     CDS.aa_pct_X    CDS  Amino_acid_composition             SSF         NB
# 3       CDS.Length    CDS                  Length             PSF      NB-OS
# 4       CDS.U-freq    CDS    Nucleotide_kmer_freq             SSF         AT
# ..             ...    ...                     ...             ...        ...
# 56   5'UTR.UA-freq  5'UTR    Nucleotide_kmer_freq             SSF         AT
# 57    3'UTR.G-freq  3'UTR    Nucleotide_kmer_freq             SSF         NB
# 58  3'UTR.AUC-freq  3'UTR    Nucleotide_kmer_freq             SSF         NB
# 59  5'UTR.UCA-freq  5'UTR    Nucleotide_kmer_freq             SSF         AT
# 60  3'UTR.GAU-freq  3'UTR    Nucleotide_kmer_freq             SSF         AT
#
#       AT_rho    NB_rho    OS_rho          AT_q           NB_q          OS_q  \
# 0  -0.118827 -0.455792 -0.219563  5.359209e-23  1.438763e-272  8.441435e-60
# 1   0.091073  0.429562  0.183228  4.278097e-14  4.248213e-239  6.201130e-42
# 2   0.090525  0.429017  0.195089  5.312467e-14  9.969284e-239  1.913352e-47
# 3  -0.090525 -0.429017 -0.195089  5.312467e-14  9.969284e-239  1.913352e-47
# 4  -0.206221 -0.132495 -0.108690  1.650200e-67   1.274393e-21  2.565595e-15
# ..       ...       ...       ...           ...            ...           ...
# 56  0.040237 -0.032140 -0.024520  9.220041e-04   2.608347e-02  8.979132e-02
# 57  0.030630 -0.036839  0.037134  1.260958e-02   1.075935e-02  8.621558e-03
# 58 -0.018981 -0.009030 -0.026988  1.255829e-01   5.340912e-01  6.011406e-02
# 59  0.004897 -0.010975  0.022803  6.906779e-01   4.584450e-01  1.112017e-01
# 60 -0.019663 -0.016343  0.018831  1.156701e-01   2.706019e-01  1.884457e-01
#
#     Max_abs_rho
# 0      0.455792
# 1      0.429562
# 2      0.429017
# 3      0.429017
# 4      0.206221
# ..          ...
# 56     0.040237
# 57     0.037134
# 58     0.026988
# 59     0.022803
# 60     0.019663
#
# [61 rows x 12 columns]

# %%
# ============================================
# 08. Global cross-species PR-effect conservation
# ============================================

from itertools import combinations

pairs = list(combinations(SPECIES_ORDER, 2))
point_color = "#8F6F6F"
rows = []

for s1, s2 in pairs:
    rho, p = safe_spearmanr(pr_effect_df[f"{s1}_rho"], pr_effect_df[f"{s2}_rho"])
    rows.append({"Species_pair": f"{s1}-{s2}", "N_features": len(pr_effect_df),
                 "Spearman_rho": rho, "P_value": p})

pr_effect_conservation_df = pd.DataFrame(rows)
display(pr_effect_conservation_df)

vals = pr_effect_df[[f"{s}_rho" for s in SPECIES_ORDER]].to_numpy(dtype=float)
lim = 1.08 * np.nanmax(np.abs(vals))

fig, axes = plt.subplots(
    1, 3, figsize=(7.5, 2.6), dpi=_PLOT_CFG["dpi"],
    sharex=True, sharey=True,
)

for ax, (s1, s2) in zip(axes, pairs):
    x, y = pr_effect_df[f"{s1}_rho"], pr_effect_df[f"{s2}_rho"]
    rho, p = safe_spearmanr(x, y)

    ax.scatter(x, y, s=20, color=point_color, alpha=0.75)
    ax.axhline(0, color="0.82", lw=0.8)
    ax.axvline(0, color="0.82", lw=0.8)

    p_text = f"{p:.2e}" if p < 0.001 else f"{p:.3f}"
    ax.text(
        0.05, 0.94,
        rf"Spearman $\rho$ = {rho:.2f}" + "\n" + rf"$p$ = {p_text}",
        transform=ax.transAxes, ha="left", va="top", fontsize=7.5,
    )

    ax.set_xlim(-lim, lim)
    ax.set_ylim(-lim, lim)
    ax.set_title(f"{s1} vs {s2}")
    ax.set_xlabel(f"{s1} PR effect")
    ax.set_ylabel(f"{s2} PR effect")

plt.tight_layout()
plt.show()
# Out:
#   Species_pair  N_features  Spearman_rho   P_value
# 0        AT-NB          61      0.531888  0.000010
# 1        AT-OS          61      0.570333  0.000002
# 2        NB-OS          61      0.551824  0.000004

# %%
# ============================================
# 09. Feature-level PR-effect divergence
# ============================================

rho_cols = [f"{s}_rho" for s in SPECIES_ORDER]

pr_divergence_df = pr_effect_df.copy()
pr_divergence_df["Effect_range"] = (
    pr_divergence_df[rho_cols].max(axis=1) - pr_divergence_df[rho_cols].min(axis=1)
)
pr_divergence_df["Effect_SD"] = pr_divergence_df[rho_cols].std(axis=1)
pr_divergence_df["Strongest_species"] = (
    pr_divergence_df[rho_cols].abs().idxmax(axis=1).str.replace("_rho", "", regex=False)
)
pr_divergence_df["Direction"] = pr_divergence_df[rho_cols].apply(
    lambda r: "Same" if len(set(np.sign(r))) == 1 else "Mixed", axis=1
)

pr_divergence_df = (
    pr_divergence_df
    .sort_values("Effect_range", ascending=False)
    .reset_index(drop=True)
)

display(
    pr_divergence_df[
        ["Feature", "Region", "Feature_type", "Selection_class", "Membership",
         "AT_rho", "NB_rho", "OS_rho", "Effect_range", "Effect_SD",
         "Strongest_species", "Direction"]
    ]
)
# Out:
#            Feature Region            Feature_type Selection_class Membership  \
# 0     CDS.aa_pct_X    CDS  Amino_acid_composition             SSF         NB
# 1       CDS.Length    CDS                  Length             PSF      NB-OS
# 2         mRNA.MFE   mRNA       RNA_structure_MFE             PSF      AT-NB
# 3      mRNA.Length   mRNA                  Length             PSF      NB-OS
# 4    mRNA.AUA-freq   mRNA    Nucleotide_kmer_freq             SSF         AT
# ..             ...    ...                     ...             ...        ...
# 56    CDS.CAA-freq    CDS    Nucleotide_kmer_freq             SSF         OS
# 57  5'UTR.UCA-freq  5'UTR    Nucleotide_kmer_freq             SSF         AT
# 58    mRNA.GU-freq   mRNA    Nucleotide_kmer_freq             SSF         NB
# 59   mRNA.GCG-freq   mRNA    Nucleotide_kmer_freq             SSF         NB
# 60  3'UTR.AUC-freq  3'UTR    Nucleotide_kmer_freq             SSF         NB
#
#       AT_rho    NB_rho    OS_rho  Effect_range  Effect_SD Strongest_species  \
# 0   0.090525  0.429017  0.195089      0.338491   0.173317                NB
# 1  -0.090525 -0.429017 -0.195089      0.338491   0.173317                NB
# 2   0.091073  0.429562  0.183228      0.338489   0.174999                NB
# 3  -0.118827 -0.455792 -0.219563      0.336965   0.172963                NB
# 4  -0.095835  0.077450  0.023229      0.173285   0.088642                AT
# ..       ...       ...       ...           ...        ...               ...
# 56  0.015531  0.017113  0.051110      0.035579   0.020101                OS
# 57  0.004897 -0.010975  0.022803      0.033779   0.016899                OS
# 58  0.058894  0.055273  0.032922      0.025973   0.014067                AT
# 59  0.045997  0.064093  0.047379      0.018096   0.010073                NB
# 60 -0.018981 -0.009030 -0.026988      0.017958   0.008997                OS
#
#    Direction
# 0       Same
# 1       Same
# 2       Same
# 3       Same
# 4      Mixed
# ..       ...
# 56      Same
# 57     Mixed
# 58      Same
# 59      Same
# 60      Same
#
# [61 rows x 12 columns]

# %%
# # ============================================
# # 10. Bootstrap cross-species PR-effect differences
# # ============================================

# N_BOOT = 2000
# rng = np.random.default_rng(42)
# rows = []

# for feature in candidate_features:
#     boot = {}

#     for sp in SPECIES_ORDER:
#         d = candidate_master_df.loc[
#             candidate_master_df["Species"].eq(sp), [feature, "observed_raw"]
#         ].dropna().to_numpy()

#         n = len(d)
#         boot[sp] = np.array([
#             safe_spearmanr(*d[rng.integers(0, n, n)].T)[0]
#             for _ in range(N_BOOT)
#         ])

#     for s1, s2 in combinations(SPECIES_ORDER, 2):
#         delta = boot[s1] - boot[s2]
#         observed = (
#             pr_effect_df.set_index("Feature").loc[feature, f"{s1}_rho"]
#             - pr_effect_df.set_index("Feature").loc[feature, f"{s2}_rho"]
#         )

#         rows.append({
#             "Feature": feature, "Species_pair": f"{s1}-{s2}",
#             "Delta_rho": observed,
#             "CI_low": np.nanquantile(delta, 0.025),
#             "CI_high": np.nanquantile(delta, 0.975),
#         })

# pr_difference_df = pd.DataFrame(rows)
# pr_difference_df["CI_excludes_zero"] = (
#     (pr_difference_df["CI_low"] > 0) | (pr_difference_df["CI_high"] < 0)
# )

# display(
#     pr_difference_df
#     .sort_values("Delta_rho", key=abs, ascending=False)
#     .reset_index(drop=True)
# )

# %%
# ============================================
# 10. Bootstrap PR effects and differences
# ============================================

N_BOOT = 2000
rng = np.random.default_rng(42)
effect_rows, diff_rows = [], []
rho_lookup = pr_effect_df.set_index("Feature")

for feature in candidate_features:
    boot = {}

    for sp in SPECIES_ORDER:
        d = candidate_master_df.loc[
            candidate_master_df["Species"].eq(sp), [feature, "observed_raw"]
        ].dropna().to_numpy()
        n = len(d)
        boot[sp] = np.array([
            safe_spearmanr(*d[rng.integers(0, n, n)].T)[0] for _ in range(N_BOOT)
        ])

        effect_rows.append({
            "Feature": feature, "Species": sp,
            "Rho": rho_lookup.loc[feature, f"{sp}_rho"],
            "CI_low": np.nanquantile(boot[sp], 0.025),
            "CI_high": np.nanquantile(boot[sp], 0.975),
        })

    for s1, s2 in combinations(SPECIES_ORDER, 2):
        delta = boot[s1] - boot[s2]
        diff_rows.append({
            "Feature": feature, "Species_pair": f"{s1}-{s2}",
            "Delta_rho": rho_lookup.loc[feature, f"{s1}_rho"] - rho_lookup.loc[feature, f"{s2}_rho"],
            "CI_low": np.nanquantile(delta, 0.025),
            "CI_high": np.nanquantile(delta, 0.975),
        })

pr_effect_ci_df = pd.DataFrame(effect_rows)
pr_difference_df = pd.DataFrame(diff_rows)

for df in [pr_effect_ci_df, pr_difference_df]:
    df["CI_excludes_zero"] = (df["CI_low"] > 0) | (df["CI_high"] < 0)

display(pr_effect_ci_df.head())
display(pr_difference_df.head())
# Out:
#           Feature Species       Rho    CI_low   CI_high  CI_excludes_zero
# 0  3'UTR.ACA-freq      AT -0.072641 -0.096547 -0.049452              True
# 1  3'UTR.ACA-freq      NB -0.038846 -0.065395 -0.012030              True
# 2  3'UTR.ACA-freq      OS -0.018380 -0.045151  0.007373             False
# 3   3'UTR.AG-freq      AT -0.021218 -0.043447  0.001270             False
# 4   3'UTR.AG-freq      NB -0.048157 -0.075030 -0.020374              True
#           Feature Species_pair  Delta_rho    CI_low   CI_high  \
# 0  3'UTR.ACA-freq        AT-NB  -0.033794 -0.069402  0.002111
# 1  3'UTR.ACA-freq        AT-OS  -0.054260 -0.088500 -0.018230
# 2  3'UTR.ACA-freq        NB-OS  -0.020466 -0.057687  0.017666
# 3   3'UTR.AG-freq        AT-NB   0.026940 -0.009761  0.061336
# 4   3'UTR.AG-freq        AT-OS  -0.086929 -0.120869 -0.054731
#
#    CI_excludes_zero
# 0             False
# 1              True
# 2             False
# 3             False
# 4              True

# %%
# # ============================================
# # 11. Summary of cross-species PR-effect differences
# # ============================================

# difference_summary_df = (
#     pr_difference_df.groupby("Species_pair", as_index=False)
#     .agg(N_features=("Feature", "size"),
#          N_CI_excludes_zero=("CI_excludes_zero", "sum"))
# )
# difference_summary_df["Percent"] = (
#     100 * difference_summary_df["N_CI_excludes_zero"]
#     / difference_summary_df["N_features"]
# )

# feature_difference_df = (
#     pr_difference_df.pivot(index="Feature", columns="Species_pair",
#                            values="CI_excludes_zero")
#     .reset_index()
# )
# pair_cols = [c for c in feature_difference_df if c != "Feature"]
# feature_difference_df["N_different_pairs"] = feature_difference_df[pair_cols].sum(axis=1)

# feature_difference_df = (
#     feature_difference_df
#     .merge(pr_divergence_df, on="Feature", validate="one_to_one")
#     .sort_values(["N_different_pairs", "Effect_range"], ascending=False)
#     .reset_index(drop=True)
# )

# print("Cross-species PR-effect differences")
# display(difference_summary_df)

# print("Number of differing species pairs per feature")
# display(
#     feature_difference_df["N_different_pairs"]
#     .value_counts().sort_index().rename_axis("N_different_pairs")
#     .reset_index(name="N_features")
# )

# display(
#     feature_difference_df[
#         ["Feature", "Selection_class", "Membership",
#          "AT_rho", "NB_rho", "OS_rho",
#          "Effect_range", "Direction", "N_different_pairs"]
#     ]
# )

# %%
# ============================================
# 11. Integrate PR-effect evidence
# ============================================

effect_wide = (
    pr_effect_ci_df
    .pivot(index="Feature", columns="Species",
           values=["Rho", "CI_low", "CI_high", "CI_excludes_zero"])
)
effect_wide.columns = [f"{sp}_{metric}" for metric, sp in effect_wide.columns]
effect_wide = effect_wide.reset_index()

diff_wide = (
    pr_difference_df
    .pivot(index="Feature", columns="Species_pair",
           values=["Delta_rho", "CI_low", "CI_high", "CI_excludes_zero"])
)
diff_wide.columns = [f"{pair}_{metric}" for metric, pair in diff_wide.columns]
diff_wide = diff_wide.reset_index()

pr_evidence_df = (
    membership_df[["Feature", "Region", "Feature_type", "Selection_class", "Membership"]]
    .merge(effect_wide, on="Feature", validate="one_to_one")
    .merge(diff_wide, on="Feature", validate="one_to_one")
)

effect_support = [f"{s}_CI_excludes_zero" for s in SPECIES_ORDER]
diff_support = [f"{p}_CI_excludes_zero" for p in ["AT-NB", "AT-OS", "NB-OS"]]

pr_evidence_df["N_supported_species"] = pr_evidence_df[effect_support].sum(axis=1).astype(int)
pr_evidence_df["N_different_pairs"] = pr_evidence_df[diff_support].sum(axis=1).astype(int)
pr_evidence_df["Effect_range"] = (
    pr_evidence_df[[f"{s}_Rho" for s in SPECIES_ORDER]].max(axis=1)
    - pr_evidence_df[[f"{s}_Rho" for s in SPECIES_ORDER]].min(axis=1)
)

pr_evidence_df = (
    pr_evidence_df
    .sort_values(["N_different_pairs", "Effect_range"], ascending=False)
    .reset_index(drop=True)
)

display(
    pr_evidence_df[
        ["Feature", "Selection_class", "Membership",
         "AT_Rho", "NB_Rho", "OS_Rho",
         "N_supported_species", "N_different_pairs", "Effect_range"]
    ]
)
# Out:
#            Feature Selection_class Membership    AT_Rho    NB_Rho    OS_Rho  \
# 0       CDS.Length             PSF      NB-OS -0.090525 -0.429017 -0.195089
# 1     CDS.aa_pct_X             SSF         NB  0.090525  0.429017  0.195089
# 2         mRNA.MFE             PSF      AT-NB  0.091073  0.429562  0.183228
# 3      mRNA.Length             PSF      NB-OS -0.118827 -0.455792 -0.219563
# 4    mRNA.AUA-freq             SSF         AT -0.095835   0.07745  0.023229
# ..             ...             ...        ...       ...       ...       ...
# 56    CDS.CAA-freq             SSF         OS  0.015531  0.017113   0.05111
# 57  5'UTR.UCA-freq             SSF         AT  0.004897 -0.010975  0.022803
# 58    mRNA.GU-freq             SSF         NB  0.058894  0.055273  0.032922
# 59   mRNA.GCG-freq             SSF         NB  0.045997  0.064093  0.047379
# 60  3'UTR.AUC-freq             SSF         NB -0.018981  -0.00903 -0.026988
#
#     N_supported_species  N_different_pairs Effect_range
# 0                     3                  3     0.338491
# 1                     3                  3     0.338491
# 2                     3                  3     0.338489
# 3                     3                  3     0.336965
# 4                     2                  3     0.173285
# ..                  ...                ...          ...
# 56                    1                  1     0.035579
# 57                    0                  0     0.033779
# 58                    3                  0     0.025973
# 59                    3                  0     0.018096
# 60                    1                  0     0.017958
#
# [61 rows x 9 columns]

# %%
# # ============================================
# # 12. Magnitude of cross-species PR divergence
# # ============================================

# pr_difference_df["Abs_delta_rho"] = pr_difference_df["Delta_rho"].abs()

# delta_summary_df = (
#     pr_difference_df.groupby("Species_pair")["Abs_delta_rho"]
#     .agg(N="size", Median="median", Mean="mean", Max="max")
#     .reset_index()
# )

# delta_bins_df = (
#     pd.cut(pr_difference_df["Abs_delta_rho"],
#            bins=[0, .05, .10, .20, np.inf],
#            labels=["<0.05", "0.05–0.10", "0.10–0.20", "≥0.20"],
#            include_lowest=True)
#     .value_counts().sort_index()
#     .rename_axis("|Δρ|").reset_index(name="N")
# )
# delta_bins_df["Percent"] = 100 * delta_bins_df["N"] / len(pr_difference_df)

# display(delta_summary_df)
# display(delta_bins_df)

# fig, ax = plt.subplots(figsize=(4, 2.8), dpi=_PLOT_CFG["dpi"])
# ax.hist(pr_difference_df["Abs_delta_rho"], bins=15, edgecolor="white")
# ax.set(xlabel=r"Absolute cross-species difference $|\Delta\rho|$",
#        ylabel="Species-pair comparisons")
# plt.tight_layout()
# plt.show()

# %%
# ============================================
# 12. PR-effect evidence structure
# ============================================

evidence_count_df = (
    pr_evidence_df
    .groupby(["N_supported_species", "N_different_pairs"])
    .size()
    .rename("N_features")
    .reset_index()
)

evidence_matrix = (
    evidence_count_df
    .pivot(index="N_supported_species",
           columns="N_different_pairs",
           values="N_features")
    .fillna(0)
    .astype(int)
    .reindex(index=range(4), columns=range(4), fill_value=0)
)

display(evidence_matrix)

fig, ax = make_fig(w=3.5, h=2.5)

im = ax.imshow(evidence_matrix, cmap="Greys", aspect="auto")

for i in range(4):
    for j in range(4):
        ax.text(j, i, evidence_matrix.iloc[i, j],
                ha="center", va="center")

ax.set(
    xlabel="Different species pairs",
    ylabel="Species with supported PR effect",
    xticks=range(4), yticks=range(4),
)

plt.colorbar(im, ax=ax, label="Number of features")
plt.show()
# Out:
# N_different_pairs    0  1   2   3
# N_supported_species
# 0                    1  1   0   0
# 1                    1  1   5   1
# 2                    0  2   8  11
# 3                    2  3  17   8

# %%
# ============================================
# 13. Cross-species PR-effect direction
# ============================================

rho_cols = [f"{s}_Rho" for s in SPECIES_ORDER]

def sign_pattern(r):
    x = r[rho_cols].to_numpy(float)
    return "".join("+" if v > 0 else "-" if v < 0 else "0" for v in x)

pr_evidence_df["Sign_pattern"] = pr_evidence_df.apply(sign_pattern, axis=1)
pr_evidence_df["Same_direction"] = (
    pr_evidence_df[rho_cols].gt(0).all(axis=1)
    | pr_evidence_df[rho_cols].lt(0).all(axis=1)
)

direction_summary_df = (
    pr_evidence_df.groupby(["Same_direction", "Sign_pattern"])
    .size().rename("N_features").reset_index()
    .sort_values("N_features", ascending=False)
)

direction_class_df = (
    pr_evidence_df["Same_direction"]
    .map({True: "Same direction", False: "Mixed direction"})
    .value_counts()
    .reindex(["Same direction", "Mixed direction"], fill_value=0)
    .rename("N_features").rename_axis("Direction_class").reset_index()
)
direction_class_df["Percent"] = 100 * direction_class_df["N_features"] / len(pr_evidence_df)

display(direction_class_df)
display(direction_summary_df)

fig, axes = plt.subplots(1, 2, figsize=(7, 2.8), dpi=_PLOT_CFG["dpi"])

axes[0].bar(direction_class_df["Direction_class"], direction_class_df["N_features"])
axes[0].set(ylabel="Number of features", xlabel="")
axes[0].tick_params(axis="x", rotation=20)

p = direction_summary_df.copy()
axes[1].bar(p["Sign_pattern"], p["N_features"])
axes[1].set(xlabel="AT / NB / OS sign pattern", ylabel="Number of features")
axes[1].tick_params(axis="x", rotation=45)

plt.tight_layout()
plt.show()

display(
    pr_evidence_df[
        ["Feature", "Selection_class", "Membership",
         "AT_Rho", "NB_Rho", "OS_Rho",
         "Sign_pattern", "Same_direction",
         "N_supported_species", "N_different_pairs", "Effect_range"]
    ]
    .sort_values(["Same_direction", "Effect_range"], ascending=[True, False])
    .reset_index(drop=True)
)
# Out:
#    Direction_class  N_features    Percent
# 0   Same direction          30  49.180328
# 1  Mixed direction          31  50.819672
#    Same_direction Sign_pattern  N_features
# 7            True          ---          20
# 5           False          --+          11
# 6            True          +++          10
# 4           False          -+-           9
# 1           False          +-+           5
# 3           False          -++           3
# 2           False          +--           2
# 0           False          ++-           1
#            Feature Selection_class Membership    AT_Rho    NB_Rho    OS_Rho  \
# 0    mRNA.AUA-freq             SSF         AT -0.095835   0.07745  0.023229
# 1    mRNA.UAG-freq             SSF         AT -0.056269  0.096711  0.065123
# 2     5'UTR.S-freq             SSF         AT -0.140297  0.008071 -0.051593
# 3   5'UTR.CUU-freq             SSF         AT -0.112048 -0.074548  0.019929
# 4    5'UTR.CU-freq             SSF         NB  -0.11853 -0.081704  0.013095
# ..             ...             ...        ...       ...       ...       ...
# 56     mRNA.Y-freq             SSF         OS -0.123443 -0.125194 -0.160176
# 57    CDS.CAA-freq             SSF         OS  0.015531  0.017113   0.05111
# 58    mRNA.GU-freq             SSF         NB  0.058894  0.055273  0.032922
# 59   mRNA.GCG-freq             SSF         NB  0.045997  0.064093  0.047379
# 60  3'UTR.AUC-freq             SSF         NB -0.018981  -0.00903 -0.026988
#
#    Sign_pattern  Same_direction  N_supported_species  N_different_pairs  \
# 0           -++           False                    2                  3
# 1           -++           False                    3                  2
# 2           -+-           False                    2                  3
# 3           --+           False                    2                  3
# 4           --+           False                    2                  3
# ..          ...             ...                  ...                ...
# 56          ---            True                    3                  1
# 57          +++            True                    1                  1
# 58          +++            True                    3                  0
# 59          +++            True                    3                  0
# 60          ---            True                    1                  0
#
#    Effect_range
# 0      0.173285
# 1       0.15298
# 2      0.148369
# 3      0.131977
# 4      0.131625
# ..          ...
# 56     0.036733
# 57     0.035579
# 58     0.025973
# 59     0.018096
# 60     0.017958
#
# [61 rows x 11 columns]

# %%
# ============================================
# 14. PR-effect support patterns
# ============================================

def support_pattern(r):
    return "-".join(s for s in SPECIES_ORDER if r[f"{s}_CI_excludes_zero"]) or "None"

# ============================================
# 14. PR-effect support patterns
# ============================================

pairs = ["AT-NB", "AT-OS", "NB-OS"]

pr_evidence_df["Supported_species"] = pr_evidence_df.apply(
    lambda r: "-".join(s for s in SPECIES_ORDER if r[f"{s}_CI_excludes_zero"]) or "None", axis=1
)
pr_evidence_df["Different_pairs"] = pr_evidence_df.apply(
    lambda r: " + ".join(p for p in pairs if r[f"{p}_CI_excludes_zero"]) or "None", axis=1
)

support_order = ["AT-NB-OS", "AT-NB", "AT-OS", "NB-OS", "AT", "NB", "OS", "None"]
diff_order = [
    "AT-NB + AT-OS + NB-OS", "AT-NB + AT-OS", "AT-NB + NB-OS",
    "AT-OS + NB-OS", "AT-NB", "AT-OS", "NB-OS", "None"
]

def summarize_pattern(col, order):
    out = (
        pr_evidence_df[col].value_counts()
        .reindex(order, fill_value=0)
        .rename("N_features").rename_axis(col).reset_index()
    )
    out["Percent"] = 100 * out["N_features"] / len(pr_evidence_df)
    return out.loc[out["N_features"] > 0].reset_index(drop=True)

support_summary_df = summarize_pattern("Supported_species", support_order)
difference_summary_df = summarize_pattern("Different_pairs", diff_order)

display(support_summary_df)
display(difference_summary_df)

fig, axes = plt.subplots(1, 2, figsize=(7, 3.2), dpi=_PLOT_CFG["dpi"])

for ax, df, col, title in [
    (axes[0], support_summary_df, "Supported_species", "Supported PR effects"),
    (axes[1], difference_summary_df, "Different_pairs", "Cross-species differences"),
]:
    y = np.arange(len(df))
    ax.barh(y, df["N_features"])
    ax.set_yticks(y, df[col])
    ax.invert_yaxis()
    ax.set(title=title, xlabel="Number of features", ylabel="")
    for i, (n, pct) in enumerate(zip(df["N_features"], df["Percent"])):
        ax.text(n + 0.3, i, f"{n} ({pct:.1f}%)", va="center", fontsize=7)

plt.tight_layout()
plt.show()
# Out:
#   Supported_species  N_features    Percent
# 0          AT-NB-OS          30  49.180328
# 1             AT-NB          10  16.393443
# 2             AT-OS           6   9.836066
# 3             NB-OS           5   8.196721
# 4                AT           3   4.918033
# 5                NB           1   1.639344
# 6                OS           4   6.557377
# 7              None           2   3.278689
#          Different_pairs  N_features    Percent
# 0  AT-NB + AT-OS + NB-OS          20  32.786885
# 1          AT-NB + AT-OS          14  22.950820
# 2          AT-NB + NB-OS           8  13.114754
# 3          AT-OS + NB-OS           8  13.114754
# 4                  AT-NB           2   3.278689
# 5                  AT-OS           5   8.196721
# 6                   None           4   6.557377

# %%
# ============================================
# 15. Joint PR-effect evidence
# ============================================

def evidence_pattern(r):
    n_sup, n_diff = r["N_supported_species"], r["N_different_pairs"]

    if n_sup == 3 and n_diff == 0 and r["Same_direction"]:
        return "Shared stable"
    if n_sup == 3 and n_diff > 0 and r["Same_direction"]:
        return "Shared divergent"
    if n_sup >= 2 and not r["Same_direction"]:
        return "Direction divergent"
    if n_sup == 2:
        return "Partial"
    if n_sup == 1:
        return "Restricted"
    return "Unsupported"

pr_evidence_df["Evidence_class"] = pr_evidence_df.apply(evidence_pattern, axis=1)

evidence_order = [
    "Shared stable", "Shared divergent", "Direction divergent",
    "Partial", "Restricted", "Unsupported",
]

evidence_summary_df = (
    pr_evidence_df["Evidence_class"].value_counts()
    .reindex(evidence_order, fill_value=0)
    .rename("N_features").rename_axis("Evidence_class").reset_index()
)
evidence_summary_df["Percent"] = 100 * evidence_summary_df["N_features"] / len(pr_evidence_df)

display(evidence_summary_df)

fig, ax = plt.subplots(figsize=(4.5, 3), dpi=_PLOT_CFG["dpi"])
ax.barh(evidence_summary_df["Evidence_class"], evidence_summary_df["N_features"])
ax.invert_yaxis()
ax.set(xlabel="Number of features", ylabel="", title="Joint PR-effect evidence")

for i, (n, p) in enumerate(zip(evidence_summary_df["N_features"], evidence_summary_df["Percent"])):
    ax.text(n + 0.2, i, f"{n} ({p:.1f}%)", va="center", fontsize=7)

plt.tight_layout()
plt.show()
# Out:
#         Evidence_class  N_features    Percent
# 0        Shared stable           2   3.278689
# 1     Shared divergent          19  31.147541
# 2  Direction divergent          26  42.622951
# 3              Partial           4   6.557377
# 4           Restricted           8  13.114754
# 5          Unsupported           2   3.278689

# %%
# ============================================
# 16. Joint evidence combinations
# ============================================

joint_summary_df = (
    pr_evidence_df
    .groupby(["N_supported_species", "N_different_pairs", "Same_direction"])
    .size().rename("N_features").reset_index()
)

joint_summary_df["Percent"] = 100 * joint_summary_df["N_features"] / len(pr_evidence_df)
joint_summary_df = joint_summary_df.sort_values(
    ["N_supported_species", "N_different_pairs", "Same_direction"],
    ascending=[False, True, False]
).reset_index(drop=True)

display(joint_summary_df)

joint_feature_df = (
    pr_evidence_df[
        ["Feature", "Region", "Feature_type", "Selection_class", "Membership",
         "AT_Rho", "NB_Rho", "OS_Rho", "Sign_pattern",
         "N_supported_species", "N_different_pairs", "Same_direction",
         "Effect_range"]
    ]
    .sort_values(["N_supported_species", "N_different_pairs", "Effect_range"],
                 ascending=[False, True, False])
    .reset_index(drop=True)
)

display(joint_feature_df)
# Out:
#     N_supported_species  N_different_pairs  Same_direction  N_features  \
# 0                     3                  0            True           2
# 1                     3                  1            True           3
# 2                     3                  2            True           8
# 3                     3                  2           False           9
# 4                     3                  3            True           8
# 5                     2                  1            True           2
# 6                     2                  2            True           2
# 7                     2                  2           False           6
# 8                     2                  3           False          11
# 9                     1                  0            True           1
# 10                    1                  1            True           1
# 11                    1                  2            True           3
# 12                    1                  2           False           2
# 13                    1                  3           False           1
# 14                    0                  0           False           1
# 15                    0                  1           False           1
#
#       Percent
# 0    3.278689
# 1    4.918033
# 2   13.114754
# 3   14.754098
# 4   13.114754
# 5    3.278689
# 6    3.278689
# 7    9.836066
# 8   18.032787
# 9    1.639344
# 10   1.639344
# 11   4.918033
# 12   3.278689
# 13   1.639344
# 14   1.639344
# 15   1.639344
#            Feature Region          Feature_type Selection_class Membership  \
# 0     mRNA.GU-freq   mRNA  Nucleotide_kmer_freq             SSF         NB
# 1    mRNA.GCG-freq   mRNA  Nucleotide_kmer_freq             SSF         NB
# 2      mRNA.K-freq   mRNA  Nucleotide_kmer_freq             SSF         OS
# 3   5'UTR.UGG-freq  5'UTR  Nucleotide_kmer_freq             SSF         NB
# 4      mRNA.Y-freq   mRNA  Nucleotide_kmer_freq             SSF         OS
# ..             ...    ...                   ...             ...        ...
# 56   5'UTR.CC-freq  5'UTR  Nucleotide_kmer_freq             SSF         OS
# 57  5'UTR.AUC-freq  5'UTR  Nucleotide_kmer_freq             SSF         NB
# 58     mRNA.U-freq   mRNA  Nucleotide_kmer_freq             SSF         OS
# 59  5'UTR.UCA-freq  5'UTR  Nucleotide_kmer_freq             SSF         AT
# 60  3'UTR.GAU-freq  3'UTR  Nucleotide_kmer_freq             SSF         AT
#
#       AT_Rho    NB_Rho    OS_Rho Sign_pattern  N_supported_species  \
# 0   0.058894  0.055273  0.032922          +++                    3
# 1   0.045997  0.064093  0.047379          +++                    3
# 2    0.02208  0.041448  0.072978          +++                    3
# 3  -0.090897 -0.044764  -0.06862          ---                    3
# 4  -0.123443 -0.125194 -0.160176          ---                    3
# ..       ...       ...       ...          ...                  ...
# 56 -0.078476 -0.026757 -0.016342          ---                    1
# 57  0.019567  0.061537  0.023443          +++                    1
# 58 -0.109898  0.018995 -0.021251          -+-                    1
# 59  0.004897 -0.010975  0.022803          +-+                    0
# 60 -0.019663 -0.016343  0.018831          --+                    0
#
#     N_different_pairs  Same_direction Effect_range
# 0                   0            True     0.025973
# 1                   0            True     0.018096
# 2                   1            True     0.050897
# 3                   1            True     0.046133
# 4                   1            True     0.036733
# ..                ...             ...          ...
# 56                  2            True     0.062134
# 57                  2            True     0.041969
# 58                  3           False     0.128893
# 59                  0           False     0.033779
# 60                  1           False     0.038494
#
# [61 rows x 13 columns]

# %%
# ============================================
# 17. Supported PR-effect direction
# ============================================

def supported_sign(r, sp):
    if not r[f"{sp}_CI_excludes_zero"]:
        return "0"
    return "+" if r[f"{sp}_Rho"] > 0 else "-"

for sp in SPECIES_ORDER:
    pr_evidence_df[f"{sp}_Sign"] = pr_evidence_df.apply(
        lambda r: supported_sign(r, sp), axis=1
    )

pr_evidence_df["Supported_sign_pattern"] = pr_evidence_df[
    [f"{s}_Sign" for s in SPECIES_ORDER]
].agg("".join, axis=1)

def supported_direction(r):
    signs = [r[f"{s}_Sign"] for s in SPECIES_ORDER if r[f"{s}_Sign"] != "0"]
    if len(signs) < 2:
        return "Not comparable"
    return "Same" if len(set(signs)) == 1 else "Opposite"

pr_evidence_df["Supported_direction"] = pr_evidence_df.apply(
    supported_direction, axis=1
)

supported_direction_summary_df = (
    pr_evidence_df.groupby(["Supported_sign_pattern", "Supported_direction"])
    .size().rename("N_features").reset_index()
    .sort_values("N_features", ascending=False).reset_index(drop=True)
)

display(supported_direction_summary_df)
# Out:
#    Supported_sign_pattern Supported_direction  N_features
# 0                     ---                Same          14
# 1                     --0                Same           7
# 2                     +++                Same           7
# 3                     -+-            Opposite           5
# 4                     +0+                Same           3
# 5                     -00      Not comparable           3
# 6                     00-      Not comparable           2
# 7                     0--                Same           2
# 8                     000      Not comparable           2
# 9                     --+            Opposite           2
# 10                    00+      Not comparable           2
# 11                    0-+            Opposite           2
# 12                    -+0            Opposite           2
# 13                    +0-            Opposite           1
# 14                    +-0            Opposite           1
# 15                    +-+            Opposite           1
# 16                    -++            Opposite           1
# 17                    -0-                Same           1
# 18                    -0+            Opposite           1
# 19                    0+0      Not comparable           1
# 20                    0++                Same           1

# %%
# ============================================
# 18. Final PR regulatory classes
# ============================================

def regulatory_class(r):
    if r["N_supported_species"] == 3 and r["Supported_direction"] == "Same" and r["N_different_pairs"] == 0:
        return "Conserved"

    if r["Supported_direction"] == "Opposite":
        return "Opposite direction"

    if r["N_supported_species"] == 1:
        sp = next(s for s in SPECIES_ORDER if r[f"{s}_CI_excludes_zero"])
        others = [s for s in SPECIES_ORDER if s != sp]
        if all(r[f"{'-'.join(sorted([sp, x], key=SPECIES_ORDER.index))}_CI_excludes_zero"] for x in others):
            return "Species-restricted"

    if r["N_supported_species"] >= 2 and r["Supported_direction"] == "Same":
        return "Partially conserved"

    return "No clear pattern"

pr_evidence_df["PR_class"] = pr_evidence_df.apply(regulatory_class, axis=1)

class_order = [
    "Conserved", "Partially conserved", "Opposite direction",
    "Species-restricted", "No clear pattern",
]

pr_class_summary_df = (
    pr_evidence_df["PR_class"].value_counts()
    .reindex(class_order, fill_value=0)
    .rename("N_features").rename_axis("PR_class").reset_index()
)
pr_class_summary_df["Percent"] = 100 * pr_class_summary_df["N_features"] / len(pr_evidence_df)

display(pr_class_summary_df)
# Out:
#               PR_class  N_features    Percent
# 0            Conserved           2   3.278689
# 1  Partially conserved          33  54.098361
# 2   Opposite direction          16  26.229508
# 3   Species-restricted           6   9.836066
# 4     No clear pattern           4   6.557377

# %%
# ============================================
# 19. Inspect final PR regulatory classes
# ============================================

cols = [
    "Feature", "Region", "Feature_type", "Selection_class", "Membership",
    "AT_Rho", "NB_Rho", "OS_Rho", "Supported_sign_pattern",
    "N_supported_species", "N_different_pairs", "Effect_range",
]

for cls in ["Conserved", "Species-restricted", "Opposite direction",
            "Partially conserved", "No clear pattern"]:
    x = (
        pr_evidence_df.loc[pr_evidence_df["PR_class"].eq(cls), cols]
        .sort_values("Effect_range", ascending=False).reset_index(drop=True)
    )
    print(f"\n{cls} (n={len(x)})")
    display(x)
# Out:
# Conserved (n=2)
#          Feature Region          Feature_type Selection_class Membership  \
# 0   mRNA.GU-freq   mRNA  Nucleotide_kmer_freq             SSF         NB
# 1  mRNA.GCG-freq   mRNA  Nucleotide_kmer_freq             SSF         NB
#
#      AT_Rho    NB_Rho    OS_Rho Supported_sign_pattern  N_supported_species  \
# 0  0.058894  0.055273  0.032922                    +++                    3
# 1  0.045997  0.064093  0.047379                    +++                    3
#
#    N_different_pairs Effect_range
# 0                  0     0.025973
# 1                  0     0.018096
# Species-restricted (n=6)
#           Feature Region          Feature_type Selection_class Membership  \
# 0   3'UTR.UC-freq  3'UTR  Nucleotide_kmer_freq             SSF         OS
# 1     mRNA.U-freq   mRNA  Nucleotide_kmer_freq             SSF         OS
# 2  5'UTR.ACU-freq  5'UTR  Nucleotide_kmer_freq             SSF         OS
# 3   5'UTR.UG-freq  5'UTR  Nucleotide_kmer_freq             SSF         NB
# 4   5'UTR.CC-freq  5'UTR  Nucleotide_kmer_freq             SSF         OS
# 5  5'UTR.AUC-freq  5'UTR  Nucleotide_kmer_freq             SSF         NB
#
#      AT_Rho    NB_Rho    OS_Rho Supported_sign_pattern  N_supported_species  \
# 0 -0.006776  0.010346 -0.120731                    00-                    1
# 1 -0.109898  0.018995 -0.021251                    -00                    1
# 2  0.013127 -0.014304   0.06146                    00+                    1
# 3 -0.082286 -0.023848 -0.009327                    -00                    1
# 4 -0.078476 -0.026757 -0.016342                    -00                    1
# 5  0.019567  0.061537  0.023443                    0+0                    1
#
#    N_different_pairs Effect_range
# 0                  2     0.131077
# 1                  3     0.128893
# 2                  2     0.075764
# 3                  2     0.072959
# 4                  2     0.062134
# 5                  2     0.041969
# Opposite direction (n=16)
#            Feature Region          Feature_type Selection_class Membership  \
# 0    mRNA.AUA-freq   mRNA  Nucleotide_kmer_freq             SSF         AT
# 1    mRNA.UAG-freq   mRNA  Nucleotide_kmer_freq             SSF         AT
# 2     CDS.CAC-freq    CDS  Nucleotide_kmer_freq             SSF         NB
# 3   5'UTR.UGC-freq  5'UTR  Nucleotide_kmer_freq             SSF         OS
# 4     5'UTR.G-freq  5'UTR  Nucleotide_kmer_freq             SSF         AT
# 5     CDS.AAA-freq    CDS  Nucleotide_kmer_freq             SSF         AT
# 6    3'UTR.AG-freq  3'UTR  Nucleotide_kmer_freq             SSF         NB
# 7    5'UTR.CG-freq  5'UTR  Nucleotide_kmer_freq             SSF         OS
# 8   3'UTR.UAG-freq  3'UTR  Nucleotide_kmer_freq             SSF         AT
# 9   5'UTR.AGG-freq  5'UTR  Nucleotide_kmer_freq             SSF         OS
# 10   mRNA.CUA-freq   mRNA  Nucleotide_kmer_freq             SSF         NB
# 11  5'UTR.UCG-freq  5'UTR  Nucleotide_kmer_freq             SSF         OS
# 12   mRNA.GCU-freq   mRNA  Nucleotide_kmer_freq             SSF         NB
# 13  5'UTR.CCG-freq  5'UTR  Nucleotide_kmer_freq             SSF         OS
# 14    3'UTR.G-freq  3'UTR  Nucleotide_kmer_freq             SSF         NB
# 15   5'UTR.UA-freq  5'UTR  Nucleotide_kmer_freq             SSF         AT
#
#       AT_Rho    NB_Rho    OS_Rho Supported_sign_pattern  N_supported_species  \
# 0  -0.095835   0.07745  0.023229                    -+0                    2
# 1  -0.056269  0.096711  0.065123                    -++                    3
# 2   0.049403  0.011249 -0.076728                    +0-                    2
# 3  -0.076532 -0.006492  0.049139                    -0+                    2
# 4  -0.044488  0.061283 -0.053125                    -+-                    3
# 5  -0.065847  0.048461 -0.044651                    -+-                    3
# 6  -0.021218 -0.048157  0.065712                    0-+                    2
# 7  -0.049681  0.062382 -0.038597                    -+-                    3
# 8  -0.046155  -0.03155  0.062105                    --+                    3
# 9  -0.075701  0.031637 -0.045833                    -+-                    3
# 10 -0.038282 -0.053179  0.047051                    --+                    3
# 11 -0.042988  0.053007 -0.013617                    -+0                    2
# 12 -0.018736 -0.042517  0.048193                    0-+                    2
# 13 -0.053221  0.027333 -0.053625                    -+-                    3
# 14   0.03063 -0.036839  0.037134                    +-+                    3
# 15  0.040237  -0.03214  -0.02452                    +-0                    2
#
#     N_different_pairs Effect_range
# 0                   3     0.173285
# 1                   2      0.15298
# 2                   3     0.126132
# 3                   3      0.12567
# 4                   2     0.114408
# 5                   2     0.114308
# 6                   2     0.113869
# 7                   2     0.112064
# 8                   2      0.10826
# 9                   2     0.107338
# 10                  2      0.10023
# 11                  2     0.095996
# 12                  2      0.09071
# 13                  2     0.080958
# 14                  2     0.073973
# 15                  2     0.072378
# Partially conserved (n=33)
#            Feature Region            Feature_type Selection_class Membership  \
# 0       CDS.Length    CDS                  Length             PSF      NB-OS
# 1     CDS.aa_pct_X    CDS  Amino_acid_composition             SSF         NB
# 2         mRNA.MFE   mRNA       RNA_structure_MFE             PSF      AT-NB
# 3      mRNA.Length   mRNA                  Length             PSF      NB-OS
# 4      CDS.AU-freq    CDS    Nucleotide_kmer_freq             SSF         AT
# 5     5'UTR.S-freq  5'UTR    Nucleotide_kmer_freq             SSF         AT
# 6     mRNA.CC-freq   mRNA    Nucleotide_kmer_freq             SSF         NB
# 7      mRNA.C-freq   mRNA    Nucleotide_kmer_freq             SSF         NB
# 8   5'UTR.CUU-freq  5'UTR    Nucleotide_kmer_freq             SSF         AT
# 9    5'UTR.CU-freq  5'UTR    Nucleotide_kmer_freq             SSF         NB
# 10  5'UTR.CUC-freq  5'UTR    Nucleotide_kmer_freq             SSF         NB
# 11       5'UTR.MFE  5'UTR       RNA_structure_MFE             PSF      AT-NB
# 12   mRNA.AAA-freq   mRNA    Nucleotide_kmer_freq             SSF         OS
# 13    mRNA.GC-freq   mRNA    Nucleotide_kmer_freq             SSF         NB
# 14    CDS.UAU-freq    CDS    Nucleotide_kmer_freq             SSF         AT
# 15   5'UTR.UC-freq  5'UTR    Nucleotide_kmer_freq             PSF      NB-OS
# 16    5'UTR.U-freq  5'UTR    Nucleotide_kmer_freq             PSF      AT-OS
# 17      CDS.U-freq    CDS    Nucleotide_kmer_freq             SSF         AT
# 18   mRNA.CCC-freq   mRNA    Nucleotide_kmer_freq             SSF         NB
# 19  5'UTR.UAU-freq  5'UTR    Nucleotide_kmer_freq             PSF      NB-OS
# 20  5'UTR.ACA-freq  5'UTR    Nucleotide_kmer_freq             SSF         NB
# 21    CDS.aa_pct_I    CDS  Amino_acid_composition             SSF         AT
# 22    5'UTR.Length  5'UTR                  Length             MSF   AT-NB-OS
# 23  5'UTR.CCC-freq  5'UTR    Nucleotide_kmer_freq             SSF         OS
# 24    mRNA.UC-freq   mRNA    Nucleotide_kmer_freq             SSF         OS
# 25    3'UTR.Length  3'UTR                  Length             SSF         OS
# 26   mRNA.GUA-freq   mRNA    Nucleotide_kmer_freq             SSF         NB
# 27  3'UTR.ACA-freq  3'UTR    Nucleotide_kmer_freq             SSF         NB
# 28     mRNA.K-freq   mRNA    Nucleotide_kmer_freq             SSF         OS
# 29  5'UTR.UGG-freq  5'UTR    Nucleotide_kmer_freq             SSF         NB
# 30  3'UTR.GUA-freq  3'UTR    Nucleotide_kmer_freq             SSF         OS
# 31   mRNA.AUC-freq   mRNA    Nucleotide_kmer_freq             SSF         AT
# 32     mRNA.Y-freq   mRNA    Nucleotide_kmer_freq             SSF         OS
#
#       AT_Rho    NB_Rho    OS_Rho Supported_sign_pattern  N_supported_species  \
# 0  -0.090525 -0.429017 -0.195089                    ---                    3
# 1   0.090525  0.429017  0.195089                    +++                    3
# 2   0.091073  0.429562  0.183228                    +++                    3
# 3  -0.118827 -0.455792 -0.219563                    ---                    3
# 4  -0.205146 -0.046785 -0.071051                    ---                    3
# 5  -0.140297  0.008071 -0.051593                    -0-                    2
# 6   -0.05143 -0.191783 -0.126671                    ---                    3
# 7  -0.061843 -0.199332  -0.11015                    ---                    3
# 8  -0.112048 -0.074548  0.019929                    --0                    2
# 9   -0.11853 -0.081704  0.013095                    --0                    2
# 10 -0.115111 -0.074276  0.013081                    --0                    2
# 11  0.171073  0.047149  0.073845                    +++                    3
# 12 -0.015893  0.101623  0.031633                    0++                    2
# 13  0.094744 -0.019142    0.0501                    +0+                    2
# 14  -0.14528 -0.033445 -0.061964                    ---                    3
# 15 -0.096476 -0.035483  0.012482                    --0                    2
# 16 -0.099232 -0.068947  0.008103                    --0                    2
# 17 -0.206221 -0.132495  -0.10869                    ---                    3
# 18 -0.073752  -0.17023 -0.133709                    ---                    3
# 19  0.003532 -0.084468 -0.065534                    0--                    2
# 20  0.074827 -0.011241  0.028605                    +0+                    2
# 21 -0.121213 -0.038696  -0.08496                    ---                    3
# 22 -0.132556 -0.095704 -0.058315                    ---                    3
# 23 -0.080351 -0.039646 -0.006319                    --0                    2
# 24 -0.114495 -0.105759 -0.175935                    ---                    3
# 25 -0.010334 -0.059297  -0.07128                    0--                    2
# 26  0.024444  0.079211  0.060757                    +++                    3
# 27 -0.072641 -0.038846  -0.01838                    --0                    2
# 28   0.02208  0.041448  0.072978                    +++                    3
# 29 -0.090897 -0.044764  -0.06862                    ---                    3
# 30  0.042946  0.002043  0.028473                    +0+                    2
# 31 -0.074831  -0.03499  -0.03947                    ---                    3
# 32 -0.123443 -0.125194 -0.160176                    ---                    3
#
#     N_different_pairs Effect_range
# 0                   3     0.338491
# 1                   3     0.338491
# 2                   3     0.338489
# 3                   3     0.336965
# 4                   2     0.158361
# 5                   3     0.148369
# 6                   3     0.140353
# 7                   3     0.137489
# 8                   3     0.131977
# 9                   3     0.131625
# 10                  3     0.128192
# 11                  2     0.123924
# 12                  3     0.117516
# 13                  3     0.113885
# 14                  2     0.111835
# 15                  3     0.108958
# 16                  2     0.107335
# 17                  2     0.097531
# 18                  3     0.096479
# 19                  2        0.088
# 20                  3     0.086067
# 21                  3     0.082518
# 22                  2      0.07424
# 23                  2     0.074031
# 24                  2     0.070176
# 25                  2     0.060946
# 26                  2     0.054767
# 27                  1      0.05426
# 28                  1     0.050897
# 29                  1     0.046133
# 30                  1     0.040903
# 31                  2     0.039841
# 32                  1     0.036733
# No clear pattern (n=4)
#           Feature Region          Feature_type Selection_class Membership  \
# 0  3'UTR.GAU-freq  3'UTR  Nucleotide_kmer_freq             SSF         AT
# 1    CDS.CAA-freq    CDS  Nucleotide_kmer_freq             SSF         OS
# 2  5'UTR.UCA-freq  5'UTR  Nucleotide_kmer_freq             SSF         AT
# 3  3'UTR.AUC-freq  3'UTR  Nucleotide_kmer_freq             SSF         NB
#
#      AT_Rho    NB_Rho    OS_Rho Supported_sign_pattern  N_supported_species  \
# 0 -0.019663 -0.016343  0.018831                    000                    0
# 1  0.015531  0.017113   0.05111                    00+                    1
# 2  0.004897 -0.010975  0.022803                    000                    0
# 3 -0.018981  -0.00903 -0.026988                    00-                    1
#
#    N_different_pairs Effect_range
# 0                  1     0.038494
# 1                  1     0.035579
# 2                  0     0.033779
# 3                  0     0.017958

# %%
# ============================================
# 20. Refine PR regulatory classes
# ============================================

def regulatory_class(r):
    n = r["N_supported_species"]

    if n == 3 and r["Supported_direction"] == "Same":
        return "Conserved" if r["N_different_pairs"] == 0 else "Quantitatively divergent"

    if n >= 2 and r["Supported_direction"] == "Opposite":
        return "Opposite direction"

    if n == 2 and r["Supported_direction"] == "Same":
        return "Partially shared"

    if n == 1:
        sp = next(s for s in SPECIES_ORDER if r[f"{s}_CI_excludes_zero"])
        related = [p for p in ["AT-NB", "AT-OS", "NB-OS"] if sp in p.split("-")]
        if all(r[f"{p}_CI_excludes_zero"] for p in related):
            return "Species-restricted"

    return "No clear pattern"

pr_evidence_df["PR_class"] = pr_evidence_df.apply(regulatory_class, axis=1)

class_order = [
    "Conserved", "Quantitatively divergent", "Partially shared",
    "Opposite direction", "Species-restricted", "No clear pattern",
]

pr_class_summary_df = (
    pr_evidence_df["PR_class"].value_counts()
    .reindex(class_order, fill_value=0)
    .rename("N_features").rename_axis("PR_class").reset_index()
)
pr_class_summary_df["Percent"] = 100 * pr_class_summary_df["N_features"] / len(pr_evidence_df)

display(pr_class_summary_df)
# Out:
#                    PR_class  N_features    Percent
# 0                 Conserved           2   3.278689
# 1  Quantitatively divergent          19  31.147541
# 2          Partially shared          14  22.950820
# 3        Opposite direction          16  26.229508
# 4        Species-restricted           6   9.836066
# 5          No clear pattern           4   6.557377

# %%
# ============================================
# 21. Predictive selection × PR response
# ============================================

selection_pr_df = pd.crosstab(
    pr_evidence_df["Selection_class"],
    pr_evidence_df["PR_class"]
).reindex(
    index=["MSF", "PSF", "SSF"],
    columns=class_order,
    fill_value=0,
)

selection_pr_pct = selection_pr_df.div(selection_pr_df.sum(axis=1), axis=0) * 100

display(selection_pr_df)
display(selection_pr_pct.round(1))

fig, axes = plt.subplots(1, 2, figsize=(8, 3), dpi=_PLOT_CFG["dpi"])

selection_pr_df.plot.bar(stacked=True, ax=axes[0], legend=False)
selection_pr_pct.plot.bar(stacked=True, ax=axes[1])

axes[0].set(xlabel="Selection class", ylabel="Number of features", title="Counts")
axes[1].set(xlabel="Selection class", ylabel="Percent", title="Within-class composition")
axes[1].legend(title="PR response", bbox_to_anchor=(1.02, 1), loc="upper left", frameon=False)

for ax in axes:
    ax.tick_params(axis="x", rotation=0)

plt.tight_layout()
plt.show()
# Out:
# PR_class         Conserved  Quantitatively divergent  Partially shared  \
# Selection_class
# MSF                      0                         1                 0
# PSF                      0                         4                 3
# SSF                      2                        14                11
#
# PR_class         Opposite direction  Species-restricted  No clear pattern
# Selection_class
# MSF                               0                   0                 0
# PSF                               0                   0                 0
# SSF                              16                   6                 4
# PR_class         Conserved  Quantitatively divergent  Partially shared  \
# Selection_class
# MSF                    0.0                     100.0               0.0
# PSF                    0.0                      57.1              42.9
# SSF                    3.8                      26.4              20.8
#
# PR_class         Opposite direction  Species-restricted  No clear pattern
# Selection_class
# MSF                             0.0                 0.0               0.0
# PSF                             0.0                 0.0               0.0
# SSF                            30.2                11.3               7.5

# %%
# ============================================
# 22. SSF membership × PR response
# ============================================

ssf_df = pr_evidence_df.query("Selection_class == 'SSF'").copy()

ssf_pr_df = pd.crosstab(
    ssf_df["Membership"], ssf_df["PR_class"]
).reindex(index=SPECIES_ORDER, columns=class_order, fill_value=0)

ssf_pr_pct = ssf_pr_df.div(ssf_pr_df.sum(axis=1), axis=0) * 100

display(ssf_pr_df)
display(ssf_pr_pct.round(1))

fig, axes = plt.subplots(1, 2, figsize=(8, 3), dpi=_PLOT_CFG["dpi"])

ssf_pr_df.plot.bar(stacked=True, ax=axes[0], legend=False)
ssf_pr_pct.plot.bar(stacked=True, ax=axes[1])

axes[0].set(title="Counts", xlabel="SSF membership", ylabel="Number of features")
axes[1].set(title="Within-species composition", xlabel="SSF membership", ylabel="Percent")
axes[1].legend(title="PR response", bbox_to_anchor=(1.02, 1), loc="upper left", frameon=False)

for ax in axes:
    ax.tick_params(axis="x", rotation=0)

plt.tight_layout()
plt.show()
# Out:
# PR_class    Conserved  Quantitatively divergent  Partially shared  \
# Membership
# AT                  0                         5                 2
# NB                  2                         6                 5
# OS                  0                         3                 4
#
# PR_class    Opposite direction  Species-restricted  No clear pattern
# Membership
# AT                           6                   0                 2
# NB                           5                   2                 1
# OS                           5                   4                 1
# PR_class    Conserved  Quantitatively divergent  Partially shared  \
# Membership
# AT                0.0                      33.3              13.3
# NB                9.5                      28.6              23.8
# OS                0.0                      17.6              23.5
#
# PR_class    Opposite direction  Species-restricted  No clear pattern
# Membership
# AT                        40.0                 0.0              13.3
# NB                        23.8                 9.5               4.8
# OS                        29.4                23.5               5.9

# %%
# ============================================
# 23. SSF selection–effect concordance
# ============================================

ssf_df = pr_evidence_df.query("Selection_class == 'SSF'").copy()
rho_cols = [f"{s}_Rho" for s in SPECIES_ORDER]

ssf_df["Strongest_species"] = (
    ssf_df[rho_cols].abs().idxmax(axis=1).str.replace("_Rho", "", regex=False)
)
ssf_df["Selection_concordant"] = ssf_df["Membership"].eq(ssf_df["Strongest_species"])

concordance_df = (
    ssf_df.groupby("Membership")["Selection_concordant"]
    .agg(N="size", N_concordant="sum").reset_index()
)
concordance_df["Percent_concordant"] = 100 * concordance_df["N_concordant"] / concordance_df["N"]

display(concordance_df)
display(
    ssf_df[["Feature", "Membership", "Strongest_species",
            "AT_Rho", "NB_Rho", "OS_Rho", "PR_class", "Selection_concordant"]]
    .sort_values(["Membership", "Selection_concordant"])
)
# Out:
#   Membership   N  N_concordant  Percent_concordant
# 0         AT  15            11           73.333333
# 1         NB  21             8           38.095238
# 2         OS  17             8           47.058824
#            Feature Membership Strongest_species    AT_Rho    NB_Rho    OS_Rho  \
# 21   mRNA.UAG-freq         AT                NB -0.056269  0.096711  0.065123
# 24    5'UTR.G-freq         AT                NB -0.044488  0.061283 -0.053125
# 29  3'UTR.UAG-freq         AT                OS -0.046155  -0.03155  0.062105
# 57  5'UTR.UCA-freq         AT                OS  0.004897 -0.010975  0.022803
# 4    mRNA.AUA-freq         AT                AT -0.095835   0.07745  0.023229
# 5     5'UTR.S-freq         AT                AT -0.140297  0.008071 -0.051593
# 8   5'UTR.CUU-freq         AT                AT -0.112048 -0.074548  0.019929
# 19    CDS.aa_pct_I         AT                AT -0.121213 -0.038696  -0.08496
# 20     CDS.AU-freq         AT                AT -0.205146 -0.046785 -0.071051
# 25    CDS.AAA-freq         AT                AT -0.065847  0.048461 -0.044651
# 28    CDS.UAU-freq         AT                AT  -0.14528 -0.033445 -0.061964
# 33      CDS.U-freq         AT                AT -0.206221 -0.132495  -0.10869
# 43   5'UTR.UA-freq         AT                AT  0.040237  -0.03214  -0.02452
# 49   mRNA.AUC-freq         AT                AT -0.074831  -0.03499  -0.03947
# 54  3'UTR.GAU-freq         AT                AT -0.019663 -0.016343  0.018831
# 9    5'UTR.CU-freq         NB                AT  -0.11853 -0.081704  0.013095
# 11  5'UTR.CUC-freq         NB                AT -0.115111 -0.074276  0.013081
# 12    CDS.CAC-freq         NB                OS  0.049403  0.011249 -0.076728
# 15    mRNA.GC-freq         NB                AT  0.094744 -0.019142    0.0501
# 18  5'UTR.ACA-freq         NB                AT  0.074827 -0.011241  0.028605
# 26   3'UTR.AG-freq         NB                OS -0.021218 -0.048157  0.065712
# 35   mRNA.GCU-freq         NB                OS -0.018736 -0.042517  0.048193
# 41    3'UTR.G-freq         NB                OS   0.03063 -0.036839  0.037134
# 42   5'UTR.UG-freq         NB                AT -0.082286 -0.023848 -0.009327
# 50  3'UTR.ACA-freq         NB                AT -0.072641 -0.038846  -0.01838
# 52  5'UTR.UGG-freq         NB                AT -0.090897 -0.044764  -0.06862
# 58    mRNA.GU-freq         NB                AT  0.058894  0.055273  0.032922
# 60  3'UTR.AUC-freq         NB                OS -0.018981  -0.00903 -0.026988
# 1     CDS.aa_pct_X         NB                NB  0.090525  0.429017  0.195089
# 6     mRNA.CC-freq         NB                NB  -0.05143 -0.191783 -0.126671
# 7      mRNA.C-freq         NB                NB -0.061843 -0.199332  -0.11015
# 17   mRNA.CCC-freq         NB                NB -0.073752  -0.17023 -0.133709
# 32   mRNA.CUA-freq         NB                NB -0.038282 -0.053179  0.047051
# 47   mRNA.GUA-freq         NB                NB  0.024444  0.079211  0.060757
# 48  5'UTR.AUC-freq         NB                NB  0.019567  0.061537  0.023443
# 59   mRNA.GCG-freq         NB                NB  0.045997  0.064093  0.047379
# 10     mRNA.U-freq         OS                AT -0.109898  0.018995 -0.021251
# 13  5'UTR.UGC-freq         OS                AT -0.076532 -0.006492  0.049139
# 14   mRNA.AAA-freq         OS                NB -0.015893  0.101623  0.031633
# 27   5'UTR.CG-freq         OS                NB -0.049681  0.062382 -0.038597
# 30  5'UTR.AGG-freq         OS                AT -0.075701  0.031637 -0.045833
# 34  5'UTR.UCG-freq         OS                NB -0.042988  0.053007 -0.013617
# 40  5'UTR.CCC-freq         OS                AT -0.080351 -0.039646 -0.006319
# 45   5'UTR.CC-freq         OS                AT -0.078476 -0.026757 -0.016342
# 53  3'UTR.GUA-freq         OS                AT  0.042946  0.002043  0.028473
# 22   3'UTR.UC-freq         OS                OS -0.006776  0.010346 -0.120731
# 37  5'UTR.CCG-freq         OS                OS -0.053221  0.027333 -0.053625
# 38  5'UTR.ACU-freq         OS                OS  0.013127 -0.014304   0.06146
# 44    mRNA.UC-freq         OS                OS -0.114495 -0.105759 -0.175935
# 46    3'UTR.Length         OS                OS -0.010334 -0.059297  -0.07128
# 51     mRNA.K-freq         OS                OS   0.02208  0.041448  0.072978
# 55     mRNA.Y-freq         OS                OS -0.123443 -0.125194 -0.160176
# 56    CDS.CAA-freq         OS                OS  0.015531  0.017113   0.05111
#
#                     PR_class  Selection_concordant
# 21        Opposite direction                 False
# 24        Opposite direction                 False
# 29        Opposite direction                 False
# 57          No clear pattern                 False
# 4         Opposite direction                  True
# 5           Partially shared                  True
# 8           Partially shared                  True
# 19  Quantitatively divergent                  True
# 20  Quantitatively divergent                  True
# 25        Opposite direction                  True
# 28  Quantitatively divergent                  True
# 33  Quantitatively divergent                  True
# 43        Opposite direction                  True
# 49  Quantitatively divergent                  True
# 54          No clear pattern                  True
# 9           Partially shared                 False
# 11          Partially shared                 False
# 12        Opposite direction                 False
# 15          Partially shared                 False
# 18          Partially shared                 False
# 26        Opposite direction                 False
# 35        Opposite direction                 False
# 41        Opposite direction                 False
# 42        Species-restricted                 False
# 50          Partially shared                 False
# 52  Quantitatively divergent                 False
# 58                 Conserved                 False
# 60          No clear pattern                 False
# 1   Quantitatively divergent                  True
# 6   Quantitatively divergent                  True
# 7   Quantitatively divergent                  True
# 17  Quantitatively divergent                  True
# 32        Opposite direction                  True
# 47  Quantitatively divergent                  True
# 48        Species-restricted                  True
# 59                 Conserved                  True
# 10        Species-restricted                 False
# 13        Opposite direction                 False
# 14          Partially shared                 False
# 27        Opposite direction                 False
# 30        Opposite direction                 False
# 34        Opposite direction                 False
# 40          Partially shared                 False
# 45        Species-restricted                 False
# 53          Partially shared                 False
# 22        Species-restricted                  True
# 37        Opposite direction                  True
# 38        Species-restricted                  True
# 44  Quantitatively divergent                  True
# 46          Partially shared                  True
# 51  Quantitatively divergent                  True
# 55  Quantitatively divergent                  True
# 56          No clear pattern                  True

# %%
# ============================================
# 24. Test SSF selection–effect concordance
# ============================================

from scipy.stats import binomtest

rows = []

for sp in ["All", *SPECIES_ORDER]:
    d = ssf_df if sp == "All" else ssf_df.query("Membership == @sp")
    k, n = d["Selection_concordant"].sum(), len(d)
    test = binomtest(k, n, p=1/3, alternative="greater")

    rows.append({
        "Membership": sp, "N": n, "N_concordant": k,
        "Percent": 100 * k / n, "P_value": test.pvalue,
    })

concordance_test_df = pd.DataFrame(rows)
concordance_test_df["FDR"] = multipletests(
    concordance_test_df["P_value"], method="fdr_bh"
)[1]

display(concordance_test_df)
# Out:
#   Membership   N  N_concordant    Percent   P_value       FDR
# 0        All  53            27  50.943396  0.006029  0.012059
# 1         AT  15            11  73.333333  0.001807  0.007229
# 2         NB  21             8  38.095238  0.399238  0.399238
# 3         OS  17             8  47.058824  0.171857  0.229142

# %%
# ============================================
# 25. SSF concordance by PR-response class
# ============================================

concordance_class_df = (
    ssf_df
    .groupby(["Membership", "PR_class", "Selection_concordant"])
    .size()
    .unstack(fill_value=0)
    .rename(columns={False: "Discordant", True: "Concordant"})
)

for col in ["Discordant", "Concordant"]:
    if col not in concordance_class_df.columns:
        concordance_class_df[col] = 0

concordance_class_df["N"] = (
    concordance_class_df["Concordant"]
    + concordance_class_df["Discordant"]
)

concordance_class_df["Percent_concordant"] = (
    100
    * concordance_class_df["Concordant"]
    / concordance_class_df["N"]
)

concordance_class_df = (
    concordance_class_df
    .reset_index()
    .sort_values(
        ["Membership", "N"],
        ascending=[True, False],
    )
)

display(concordance_class_df)
# Out:
# Selection_concordant Membership                  PR_class  Discordant  \
# 1                            AT        Opposite direction           3
# 3                            AT  Quantitatively divergent           0
# 0                            AT          No clear pattern           1
# 2                            AT          Partially shared           0
# 8                            NB  Quantitatively divergent           1
# 6                            NB        Opposite direction           4
# 7                            NB          Partially shared           5
# 4                            NB                 Conserved           1
# 9                            NB        Species-restricted           1
# 5                            NB          No clear pattern           1
# 11                           OS        Opposite direction           4
# 12                           OS          Partially shared           3
# 14                           OS        Species-restricted           2
# 13                           OS  Quantitatively divergent           0
# 10                           OS          No clear pattern           0
#
# Selection_concordant  Concordant  N  Percent_concordant
# 1                              3  6           50.000000
# 3                              5  5          100.000000
# 0                              1  2           50.000000
# 2                              2  2          100.000000
# 8                              5  6           83.333333
# 6                              1  5           20.000000
# 7                              0  5            0.000000
# 4                              1  2           50.000000
# 9                              1  2           50.000000
# 5                              0  1            0.000000
# 11                             1  5           20.000000
# 12                             1  4           25.000000
# 14                             2  4           50.000000
# 13                             3  3          100.000000
# 10                             1  1          100.000000

# %%
# ============================================
# 26. SSF selected-species PR-effect advantage
# ============================================

rows = []

for _, r in ssf_df.iterrows():
    selected = r["Membership"]
    others = [s for s in SPECIES_ORDER if s != selected]

    selected_effect = abs(r[f"{selected}_Rho"])
    other_effects = [abs(r[f"{s}_Rho"]) for s in others]

    rows.append({
        "Feature": r["Feature"],
        "Membership": selected,
        "PR_class": r["PR_class"],
        "Selected_abs_rho": selected_effect,
        "Other_mean_abs_rho": np.mean(other_effects),
        "Effect_advantage": selected_effect - np.mean(other_effects),
    })

ssf_advantage_df = pd.DataFrame(rows)

# Summary
advantage_summary_df = (
    ssf_advantage_df
    .groupby("Membership")["Effect_advantage"]
    .agg(["count", "median", "mean"])
    .reset_index()
)

display(advantage_summary_df)

# Individual features
display(
    ssf_advantage_df
    .sort_values("Effect_advantage", ascending=False)
    .reset_index(drop=True)
)

# Plot
fig, ax = make_fig(w=4.5, h=4)

plot_data = [
    ssf_advantage_df.loc[
        ssf_advantage_df["Membership"].eq(sp),
        "Effect_advantage",
    ].to_numpy()
    for sp in SPECIES_ORDER
]

ax.boxplot(
    plot_data,
    tick_labels=SPECIES_ORDER,
    showfliers=False,
)

for i, sp in enumerate(SPECIES_ORDER, start=1):
    y = ssf_advantage_df.loc[
        ssf_advantage_df["Membership"].eq(sp),
        "Effect_advantage",
    ]

    x = np.full(len(y), i, dtype=float)
    x += np.random.default_rng(42 + i).normal(0, 0.04, len(y))

    ax.scatter(
        x,
        y,
        alpha=0.7,
        s=25,
    )

ax.axhline(
    0,
    color="black",
    linestyle="--",
    linewidth=1,
)

ax.set_xlabel("SSF membership")
ax.set_ylabel(
    r"Selected-species $|\rho|$ − mean other-species $|\rho|$"
)

plt.show()
# Out:
#   Membership  count    median      mean
# 0         AT     15  0.037601  0.042029
# 1         NB     21  0.009365  0.023921
# 2         OS     17  0.007627  0.010651
#            Feature Membership                  PR_class  Selected_abs_rho  \
# 0     CDS.aa_pct_X         NB  Quantitatively divergent          0.429017
# 1      CDS.AU-freq         AT  Quantitatively divergent          0.205146
# 2      mRNA.C-freq         NB  Quantitatively divergent          0.199332
# 3    3'UTR.UC-freq         OS        Species-restricted          0.120731
# 4     5'UTR.S-freq         AT          Partially shared          0.140297
# 5     mRNA.CC-freq         NB  Quantitatively divergent          0.191783
# 6     CDS.UAU-freq         AT  Quantitatively divergent          0.145280
# 7       CDS.U-freq         AT  Quantitatively divergent          0.206221
# 8    mRNA.CCC-freq         NB  Quantitatively divergent          0.170230
# 9     mRNA.UC-freq         OS  Quantitatively divergent          0.175935
# 10  5'UTR.CUU-freq         AT          Partially shared          0.112048
# 11    CDS.aa_pct_I         AT  Quantitatively divergent          0.121213
# 12  5'UTR.ACU-freq         OS        Species-restricted          0.061460
# 13   mRNA.AUA-freq         AT        Opposite direction          0.095835
# 14     mRNA.K-freq         OS  Quantitatively divergent          0.072978
# 15  5'UTR.AUC-freq         NB        Species-restricted          0.061537
# 16   mRNA.AUC-freq         AT  Quantitatively divergent          0.074831
# 17   mRNA.GUA-freq         NB  Quantitatively divergent          0.079211
# 18    3'UTR.Length         OS          Partially shared          0.071280
# 19     mRNA.Y-freq         OS  Quantitatively divergent          0.160176
# 20    CDS.CAA-freq         OS          No clear pattern          0.051110
# 21    CDS.AAA-freq         AT        Opposite direction          0.065847
# 22   mRNA.GCG-freq         NB                 Conserved          0.064093
# 23   5'UTR.CU-freq         NB          Partially shared          0.081704
# 24  5'UTR.CCG-freq         OS        Opposite direction          0.053625
# 25   5'UTR.UA-freq         AT        Opposite direction          0.040237
# 26   mRNA.CUA-freq         NB        Opposite direction          0.053179
# 27  5'UTR.CUC-freq         NB          Partially shared          0.074276
# 28    mRNA.GU-freq         NB                 Conserved          0.055273
# 29   mRNA.GCU-freq         NB        Opposite direction          0.042517
# 30  5'UTR.UGC-freq         OS        Opposite direction          0.049139
# 31  3'UTR.GUA-freq         OS          Partially shared          0.028473
# 32   3'UTR.AG-freq         NB        Opposite direction          0.048157
# 33    3'UTR.G-freq         NB        Opposite direction          0.036839
# 34  3'UTR.GAU-freq         AT          No clear pattern          0.019663
# 35  3'UTR.UAG-freq         AT        Opposite direction          0.046155
# 36  3'UTR.ACA-freq         NB          Partially shared          0.038846
# 37  5'UTR.AGG-freq         OS        Opposite direction          0.045833
# 38  5'UTR.UCA-freq         AT          No clear pattern          0.004897
# 39    5'UTR.G-freq         AT        Opposite direction          0.044488
# 40  3'UTR.AUC-freq         NB          No clear pattern          0.009030
# 41   5'UTR.CG-freq         OS        Opposite direction          0.038597
# 42   5'UTR.UG-freq         NB        Species-restricted          0.023848
# 43   mRNA.UAG-freq         AT        Opposite direction          0.056269
# 44   mRNA.AAA-freq         OS          Partially shared          0.031633
# 45  5'UTR.UCG-freq         OS        Opposite direction          0.013617
# 46  5'UTR.UGG-freq         NB  Quantitatively divergent          0.044764
# 47   5'UTR.CC-freq         OS        Species-restricted          0.016342
# 48  5'UTR.ACA-freq         NB          Partially shared          0.011241
# 49     mRNA.U-freq         OS        Species-restricted          0.021251
# 50    CDS.CAC-freq         NB        Opposite direction          0.011249
# 51    mRNA.GC-freq         NB          Partially shared          0.019142
# 52  5'UTR.CCC-freq         OS          Partially shared          0.006319
#
#     Other_mean_abs_rho  Effect_advantage
# 0             0.142807          0.286209
# 1             0.058918          0.146228
# 2             0.085996          0.113336
# 3             0.008561          0.112170
# 4             0.029832          0.110465
# 5             0.089050          0.102733
# 6             0.047705          0.097575
# 7             0.120593          0.085629
# 8             0.103730          0.066500
# 9             0.110127          0.065808
# 10            0.047238          0.064810
# 11            0.061828          0.059386
# 12            0.013716          0.047744
# 13            0.050339          0.045496
# 14            0.031764          0.041213
# 15            0.021505          0.040032
# 16            0.037230          0.037601
# 17            0.042601          0.036610
# 18            0.034816          0.036465
# 19            0.124318          0.035858
# 20            0.016322          0.034788
# 21            0.046556          0.019291
# 22            0.046688          0.017405
# 23            0.065812          0.015892
# 24            0.040277          0.013348
# 25            0.028330          0.011907
# 26            0.042667          0.010512
# 27            0.064096          0.010180
# 28            0.045908          0.009365
# 29            0.033465          0.009053
# 30            0.041512          0.007627
# 31            0.022495          0.005978
# 32            0.043465          0.004693
# 33            0.033882          0.002958
# 34            0.017587          0.002077
# 35            0.046827         -0.000672
# 36            0.045510         -0.006664
# 37            0.053669         -0.007836
# 38            0.016889         -0.011992
# 39            0.057204         -0.012716
# 40            0.022984         -0.013955
# 41            0.056032         -0.017435
# 42            0.045807         -0.021958
# 43            0.080917         -0.024648
# 44            0.058758         -0.027125
# 45            0.047998         -0.034381
# 46            0.079759         -0.034995
# 47            0.052616         -0.036274
# 48            0.051716         -0.040475
# 49            0.064446         -0.043196
# 50            0.063066         -0.051817
# 51            0.072422         -0.053280
# 52            0.059998         -0.053679

# %%
# ============================================
# 27. Test SSF PR-effect advantage
# ============================================

from scipy.stats import wilcoxon

rows = []

for group in ["All"] + SPECIES_ORDER:
    x = (
        ssf_advantage_df["Effect_advantage"]
        if group == "All"
        else ssf_advantage_df.loc[
            ssf_advantage_df["Membership"].eq(group), "Effect_advantage"
        ]
    )

    stat, p = wilcoxon(x, alternative="greater")

    rows.append({
        "Membership": group,
        "N": len(x),
        "Median_advantage": x.median(),
        "Mean_advantage": x.mean(),
        "N_positive": (x > 0).sum(),
        "Percent_positive": (x > 0).mean() * 100,
        "P_value": p,
    })

advantage_test_df = pd.DataFrame(rows)
advantage_test_df["FDR"] = multipletests(
    advantage_test_df["P_value"], method="fdr_bh"
)[1]

display(advantage_test_df)
# Out:
#   Membership   N  Median_advantage  Mean_advantage  N_positive  \
# 0        All  53          0.010512        0.024790          35
# 1         AT  15          0.037601        0.042029          11
# 2         NB  21          0.009365        0.023921          14
# 3         OS  17          0.007627        0.010651          10
#
#    Percent_positive   P_value       FDR
# 0         66.037736  0.004565  0.012451
# 1         73.333333  0.006226  0.012451
# 2         66.666667  0.128624  0.171499
# 3         58.823529  0.215340  0.215340
